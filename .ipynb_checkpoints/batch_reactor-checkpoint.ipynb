# %%
import pyomo.environ as pyo
import math
from pyDOE2 import fullfact
import pandas as pd
import numpy as np
from scipy import stats
import pyomo.dae as dae
import matplotlib.pyplot as plt
from pyomo.contrib.parmest.experiment import Experiment
from pyomo.contrib.doe import DesignOfExperiments
from pyomo.contrib.parmest import parmest

# %% [markdown]
# ## Create a model for the lab-scale batch reactor for scaling-up the Williams-Otto process

# %%
# def batch_reactor_model_const(XA0, XB0, temp, meas_sample_time):
#     """
#     Solves an experimental batch reactor model for the Williams-Otto process

#     Parameters
#     ----------
#     XA0: float, initial mass fraction of species A
#     XB0: float, initial mass fraction of species B
#     temp: int or float, constant reaction temperature in R
#     meas_sample_time: list, timepoints (hr) to collect samples for mass fraction measurements

#     Returns
#     -------
#     measured_variables: list, mass fraction of all species at the sample timepoints
#     """
#     model = pyo.ConcreteModel()

#     # define sets
#     reaction_number = [1, 2, 3]
#     model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

#     # define the model parameters
#     model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
#     model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
#     model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
#     model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
#     model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
#     model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
#     # add the mass fraction variables
#     model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
#     model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
#     model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

#     # add the temperature variables
#     model.T_reparam = pyo.Var(bounds=(0, 1))
#     model.T_reparam.fix(1/temp)

#     # add the rate constants
#     model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
#     model.k = pyo.Var(reaction_number, bounds=(0, None))
    
#     # calculate the reparameterized rate constants
#     def k_reparam_rule(m, i):
#         if i == 1:
#             return m.k_reparam[i] == pyo.log(m.a1) - m.E1 * m.T_reparam
#         elif i == 2:
#             return m.k_reparam[i] == pyo.log(m.a2) - m.E2 * m.T_reparam
#         else:
#             return m.k_reparam[i] == pyo.log(m.a3) - m.E3 * m.T_reparam
            
#     model.k_reparam_eq = pyo.Constraint(
#         reaction_number, rule=k_reparam_rule
#     )
    
#     # calculate the original rate constants
#     def k_rule(m, i):
#         return m.k[i] == pyo.exp(m.k_reparam[i])
    
#     model.k_eq = pyo.Constraint(
#         reaction_number, rule=k_rule
#     )

#     # reaction rates
#     model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
#     # define the rate of reactions
#     def reaction_rate_rule(m, i, t):
#         if i == 1:
#             return m.r[i, t] == m.k[i] * m.XA[t] * m.XB[t]
#         elif i == 2:
#             return m.r[i, t] == m.k[i] * m.XB[t] * m.XC[t]
#         else:
#             return m.r[i, t] == m.k[i] * m.XC[t] * m.XP[t]
    
#     model.reaction_rate = pyo.Constraint(
#         reaction_number, model.t, rule=reaction_rate_rule
#     )

#     # add the differential equations for XA, XB, XC, XE, XP, and XG
#     model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
#     model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
#     model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
#     model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
#     model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
#     model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

#     @model.Constraint(model.t)
#     def xa_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXA[t] == - m.r[1, t]
    
#     @model.Constraint(model.t)
#     def xb_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

#     @model.Constraint(model.t)
#     def xc_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

#     @model.Constraint(model.t)
#     def xe_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXE[t] == 2 * m.r[2, t]
    
#     @model.Constraint(model.t)
#     def xg_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXG[t] == 1.5 * m.r[3, t]

#     # add the mass fraction constraint
#     @model.Constraint(model.t)
#     def sum_mass_fraction(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

#     # fix the initial conditions
#     t0 = model.t.first()
#     model.XA[t0].fix(XA0)
#     model.XB[t0].fix(XB0)
#     model.XC[t0].fix(0)
#     model.XE[t0].fix(0)
#     model.XP[t0].fix(0)
#     model.XG[t0].fix(0)

#     # discretize the model
#     disc = pyo.TransformationFactory("dae.finite_difference")
#     disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
#     # define the solver
#     solver = pyo.SolverFactory('ipopt')
    
#     # solve the model
#     results = solver.solve(model, tee=True)
#     # model.pprint()

#     # get the mass fraction of all species
#     time = [t for t in model.t]
#     print("The timepoints are:",time)
#     XA_values = [pyo.value(model.XA[t]) for t in model.t]
#     XB_values = [pyo.value(model.XB[t]) for t in model.t] 
#     XC_values = [pyo.value(model.XC[t]) for t in model.t] 
#     XP_values = [pyo.value(model.XP[t]) for t in model.t] 
#     XE_values = [pyo.value(model.XE[t]) for t in model.t] 
#     XG_values = [pyo.value(model.XG[t]) for t in model.t] 
    
#     # Plot the results
#     plt.figure(figsize=(8, 6))
#     plt.plot(time, XA_values, label='$\mathrm{X_{A}}$')
#     plt.plot(time, XB_values, label='$\mathrm{X_{B}}$')
#     plt.plot(time, XC_values, label='$\mathrm{X_{C}}$')
#     plt.plot(time, XP_values, label='$\mathrm{X_{P}}$')
#     plt.plot(time, XE_values, label='$\mathrm{X_{E}}$')
#     plt.plot(time, XG_values, label='$\mathrm{X_{G}}$')
#     plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
#     plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
#     plt.xticks(fontsize=14)
#     plt.yticks(fontsize=14)
#     plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
#     # plt.savefig("batch_reactor_const_temp.png")
#     plt.show()

#     # store the mass fraction of all species at the sample time
#     measured_variables = []
#     for sample_time in meas_sample_time:
#         measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
#                                    pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

#     print("Mass fraction of species at the sample time:",measured_variables)
#     return measured_variables

# %%
# const_temp = 6.75
# meas_sample_time = [0.5, 1.5, 3]

# measured_var = batch_reactor_model_const(0.4, 0.6, const_temp, meas_sample_time)

# %%
def batch_reactor_model(XA0, XB0, temp_control_points, meas_sample_time):
    """
    Solves an experimental batch reactor model for the Williams-Otto process

    Parameters
    ----------
    XA0: float, initial mass fraction of species A
    XB0: float, initial mass fraction of species B
    temp_control_points: dict, timepoints (in hr) for a step change in the temperature (in R) of the reaction
    meas_sample_time: list, timepoints (hr) to collect samples for mass fraction measurements

    Returns
    -------
    measured_variables: list, mass fraction of all species at the sample timepoints
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
    model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
    model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
    model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
    model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
    model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == pyo.log(m.a1) - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == pyo.log(m.a2) - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == pyo.log(m.a3) - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.r[1, t] 
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.r[2, t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.r[3, t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA[t0].fix(XA0)
    model.XB[t0].fix(XB0)
    model.XC[t0].fix(0)
    model.XE[t0].fix(0)
    model.XP[t0].fix(0)
    model.XG[t0].fix(0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-constant temperature profile
    for t in model.t:
        if t < 0.5:
            model.T_reparam[t].fix(1/temp_control_points["0.0"])
        elif t >= 0.5 and t < 1:
            model.T_reparam[t].fix(1/temp_control_points["0.5"])
        elif t >= 1 and t < 1.5:
            model.T_reparam[t].fix(1/temp_control_points["1.0"])
        elif t >= 1.5 and t < 2:
            model.T_reparam[t].fix(1/temp_control_points["1.5"])
        elif t >= 2 and t < 2.5:
            model.T_reparam[t].fix(1/temp_control_points["2.0"])
        else:
            model.T_reparam[t].fix(1/temp_control_points["2.5"])
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    # model.pprint()

    # get the mass fraction of all species
    time = [t for t in model.t]
    print("The timepoints are:",time)
    XA_values = [pyo.value(model.XA[t]) for t in model.t]
    XB_values = [pyo.value(model.XB[t]) for t in model.t] 
    XC_values = [pyo.value(model.XC[t]) for t in model.t] 
    XP_values = [pyo.value(model.XP[t]) for t in model.t] 
    XE_values = [pyo.value(model.XE[t]) for t in model.t] 
    XG_values = [pyo.value(model.XG[t]) for t in model.t] 
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(time, XA_values, label='$\mathrm{X_{A}}$')
    plt.plot(time, XB_values, label='$\mathrm{X_{B}}$')
    plt.plot(time, XC_values, label='$\mathrm{X_{C}}$')
    plt.plot(time, XP_values, label='$\mathrm{X_{P}}$')
    plt.plot(time, XE_values, label='$\mathrm{X_{E}}$')
    plt.plot(time, XG_values, label='$\mathrm{X_{G}}$')
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
    plt.savefig("batch_reactor_var_temp.png")
    plt.show()

    # store the mass fraction of all species at the sample time
    measured_variables = []
    for sample_time in meas_sample_time:
        measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
                                   pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

    print("Mass fraction of species at the sample time:",measured_variables)
    return measured_variables

# %%
temp_control = {"0.0":5.8, "0.5":6.0, "1.0":6.2, "1.5":6.4, "2.0":6.6, "2.5":6.8}
meas_sample_time = [0.5, 1.5, 3]

measured_var = batch_reactor_model(0.4, 0.6, temp_control, meas_sample_time)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
# ...

# %% [markdown]
# ## Generate data using the ground-truth model simulations

# %%
# name of experiment inputs
input_names = ["Time"]

# name of experiment outputs
output_names = ["XA", "XB", "XC", "XP", "XE", "XG"]

# inputs dataframe
inputs_df = pd.DataFrame(meas_sample_time, columns=input_names)

# outputs dataframe
outputs_df = pd.DataFrame(measured_var, columns=output_names)

print(inputs_df)
print(outputs_df)
# Out:
#    Time
# 0   0.5
# 1   1.5
# 2   3.0
#          XA        XB        XC        XP        XE        XG
# 0  0.154933  0.162671  0.053092  0.166004  0.384525  0.078775
# 1  0.063169  0.017100  0.002532  0.156574  0.492138  0.268486
# 2  0.047195  0.000051  0.000003  0.141485  0.494288  0.316978

# %% [markdown]
# ### Add Gaussian noise

# %%
# get the mass fraction of A
XA_mass_frac = outputs_df["XA"]

# standard deviation
mass_frac_std = 0.01

# creating gaussian noise
np.random.seed(10)
XA_noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(XA_mass_frac))

# corrupt the mass fraction with the noise
noisy_XA_mass_frac = XA_mass_frac + XA_noise

# %%
# get the mass fraction of B
XB_mass_frac = outputs_df["XB"]

# standard deviation
XB_XC_mass_frac_std = 1e-06

# creating gaussian noise
np.random.seed(10)
XB_noise = stats.norm.rvs(loc=0, scale=XB_XC_mass_frac_std, size=len(XB_mass_frac))

# corrupt the mass fraction with the noise
noisy_XB_mass_frac = XB_mass_frac + XB_noise

# %%
# get the mass fraction of C
XC_mass_frac = outputs_df["XC"]

# creating gaussian noise
np.random.seed(10)
XC_noise = stats.norm.rvs(loc=0, scale=XB_XC_mass_frac_std, size=len(XC_mass_frac))

# corrupt the mass fraction with the noise
noisy_XC_mass_frac = XC_mass_frac + XC_noise

# %%
# get the mass fraction of P
XP_mass_frac = outputs_df["XP"]

# creating gaussian noise
np.random.seed(10)
XP_noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(XP_mass_frac))

# corrupt the mass fraction with the noise
noisy_XP_mass_frac = XP_mass_frac + XP_noise

# %%
# get the mass fraction of E
XE_mass_frac = outputs_df["XE"]

# creating gaussian noise
np.random.seed(10)
XE_noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(XE_mass_frac))

# corrupt the mass fraction with the noise
noisy_XE_mass_frac = XE_mass_frac + XE_noise

# %%
# get the mass fraction of P
XG_mass_frac = outputs_df["XG"]

# creating gaussian noise
np.random.seed(10)
XG_noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(XG_mass_frac))

# corrupt the mass fraction with the noise
noisy_XG_mass_frac = XG_mass_frac + XG_noise

# %%
# data columns
column_names = ["Time", "XA", "XB", "XC", "XP", "XE", "XG"]

# number of data columns
n_columns = len(column_names)

# number of data points
n_data = len(meas_sample_time)

data_matrix = np.zeros((n_data, n_columns))
data_matrix[:, 0] = meas_sample_time
data_matrix[:, 1] = noisy_XA_mass_frac
data_matrix[:, 2] = noisy_XB_mass_frac
data_matrix[:, 3] = noisy_XC_mass_frac
data_matrix[:, 4] = noisy_XP_mass_frac
data_matrix[:, 5] = noisy_XE_mass_frac
data_matrix[:, 6] = noisy_XG_mass_frac

# full data
data = pd.DataFrame(data_matrix, columns=column_names)
print(data)

data.to_csv("batch_reactor_data.csv", index=False)
# Out:
#    Time        XA        XB        XC        XP        XE        XG
# 0   0.5  0.168249  0.162672  0.053093  0.179320  0.397841  0.092091
# 1   1.5  0.070322  0.017101  0.002533  0.163727  0.499291  0.275639
# 2   3.0  0.031741  0.000050  0.000001  0.126031  0.478834  0.301524

# %% [markdown]
# ## Estimate the reaction kinetics model parameters from the data

# %%
# def batch_reactor_model_const_exp(XA0, XB0, temp):
#     """
#     Solves an experimental batch reactor model for the Williams-Otto process

#     Parameters
#     ----------
#     XA0: float, initial mass fraction of species A
#     XB0: float, initial mass fraction of species B
#     temp: int or float, constant reaction temperature in R

#     Returns
#     -------
#     model: Pyomo model of the batch reactor
    
#     """
#     model = pyo.ConcreteModel()

#     # define sets
#     reaction_number = [1, 2, 3]
#     model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

#     # define the model parameters
#     model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
#     model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
#     model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
#     model.E1 = pyo.Var(bounds=(0, None), initialize=50)
#     model.E2 = pyo.Var(bounds=(0, None), initialize=50)
#     model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
#     # add the mass fraction variables
#     model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
#     model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
#     model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
#     model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

#     # add the temperature variables
#     model.T_reparam = pyo.Var(bounds=(0, 1))
#     model.T_reparam.fix(1/temp)

#     # add the rate constants
#     model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
#     model.k = pyo.Var(reaction_number, bounds=(0, None))
    
#     # calculate the reparameterized rate constants
#     def k_reparam_rule(m, i):
#         if i == 1:
#             return m.k_reparam[i] == model.alpha_1 - m.E1 * m.T_reparam
#         elif i == 2:
#             return m.k_reparam[i] == model.alpha_2 - m.E2 * m.T_reparam
#         else:
#             return m.k_reparam[i] == model.alpha_3 - m.E3 * m.T_reparam
            
#     model.k_reparam_eq = pyo.Constraint(
#         reaction_number, rule=k_reparam_rule
#     )
    
#     # calculate the original rate constants
#     def k_rule(m, i):
#         return m.k[i] == pyo.exp(m.k_reparam[i])
    
#     model.k_eq = pyo.Constraint(
#         reaction_number, rule=k_rule
#     )

#     # add the differential equations for XA, XB, XC, XE, XP, and XG
#     model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
#     model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
#     model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
#     model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
#     model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
#     model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

#     @model.Constraint(model.t)
#     def xa_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXA[t] == - m.k[1] * m.XA[t] * m.XB[t]
    
#     @model.Constraint(model.t)
#     def xb_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXB[t] == - (m.k[1] * m.XA[t] * m.XB[t] + m.k[2] * m.XB[t] * m.XC[t])
    
#     @model.Constraint(model.t)
#     def xc_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXC[t] == 2 * m.k[1] * m.XA[t] * m.XB[t] - 2 * m.k[2] * m.XB[t] * m.XC[t] - m.k[3] * m.XC[t] * m.XP[t]
    
#     @model.Constraint(model.t)
#     def xe_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXE[t] == 2 * m.k[2] * m.XB[t] * m.XC[t]
    
#     @model.Constraint(model.t)
#     def xg_rate_ode(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.dXG[t] == 1.5 * m.k[3] * m.XC[t] * m.XP[t]

#     # add the mass fraction constraint
#     @model.Constraint(model.t)
#     def sum_mass_fraction(m, t):
#         if t == m.t.first():
#             return pyo.Constraint.Skip
#         return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

#     # fix the initial conditions
#     t0 = model.t.first()
#     model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
#     model.XB_init = pyo.Constraint(expr=model.XB[t0] == XB0)
#     model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
#     model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
#     model.XP_init = pyo.Constraint(expr=model.XP[t0] == 0.0)
#     model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

#     # discretize the model
#     disc = pyo.TransformationFactory("dae.finite_difference")
#     disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
#     # define the solver
#     solver = pyo.SolverFactory('ipopt')
    
#     # solve the model
#     results = solver.solve(model, tee=True)
    
#     return model

# %%
def batch_reactor_model_exp(XA0, XB0, temp_control_points):
    """
    Solves an experimental batch reactor model for the Williams-Otto process

    Parameters
    ----------
    XA0: float, initial mass fraction of species A
    XB0: float, initial mass fraction of species B
    temp_control_points: dict, timepoints (in hr) for a step change in the temperature (in R) of the reaction

    Returns
    -------
    model: Pyomo model of the batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == model.alpha_1 - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == model.alpha_2 - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == model.alpha_3 - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.k[1, t] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.k[1, t] * m.XA[t] * m.XB[t] + m.k[2, t] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.k[1, t] * m.XA[t] * m.XB[t] - 2 * m.k[2, t] * m.XB[t] * m.XC[t] - m.k[3, t] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.k[2, t] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.k[3, t] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == XB0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XP_init = pyo.Constraint(expr=model.XP[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-constant temperature profile
    for t in model.t:
        if t < 0.5:
            model.T_reparam[t].fix(1/temp_control_points["0.0"])
        elif t >= 0.5 and t < 1:
            model.T_reparam[t].fix(1/temp_control_points["0.5"])
        elif t >= 1 and t < 1.5:
            model.T_reparam[t].fix(1/temp_control_points["1.0"])
        elif t >= 1.5 and t < 2:
            model.T_reparam[t].fix(1/temp_control_points["1.5"])
        elif t >= 2 and t < 2.5:
            model.T_reparam[t].fix(1/temp_control_points["2.0"])
        else:
            model.T_reparam[t].fix(1/temp_control_points["2.5"])
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %%
class BatchReactorExperiment(Experiment):

    def __init__(self, data, XA0, XB0, temp_control):

        self.data = data
        self.XA0 = XA0
        self.XB0 = XB0
        self.temp_control = temp_control
        self.model = None

    def get_labeled_model(self):
        self.create_model()
        self.label_model()

        return self.model

    def create_model(self):
        self.model = batch_reactor_model_exp(self.XA0, self.XB0, self.temp_control)
        # self.model = batch_reactor_model_const_exp(self.XA0, self.XB0, self.temp_control)

        return self.model

    def label_model(self):

        m = self.model

        meas_time_points = self.data["Time"]

        # label the measured variables
        m.experiment_outputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.experiment_outputs.update(
            (m.XA[t], self.data["XA"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XB[t], self.data["XB"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XC[t], self.data["XC"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XP[t], self.data["XP"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XE[t], self.data["XE"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XG[t], self.data["XG"][ind]) for ind, t in enumerate(meas_time_points)
        )

        # label the unknown parameters
        m.unknown_parameters = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.unknown_parameters.update(
            (k, pyo.ComponentUID(k)) for k in [m.alpha_1, m.alpha_2, m.alpha_3, m.E1, m.E2, m.E3]
        )

        # add the measurement errors
        m.measurement_error = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.measurement_error.update(
            (m.XA[t], mass_frac_std) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XB[t], XB_XC_mass_frac_std) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XC[t], XB_XC_mass_frac_std) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XP[t], mass_frac_std) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XE[t], mass_frac_std) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XG[t], mass_frac_std) for t in meas_time_points
        )

        return m

# %%
# create the list of the experiment class
exp_list = [BatchReactorExperiment(data, 0.4, 0.6, temp_control)]
# exp_list = [BatchReactorExperiment(data, 0.4, 0.6, const_temp)]

# Create the Estimator object
pest = parmest.Estimator(exp_list, obj_function="SSE_weighted", tee=True)  

# Estimate the parameters
obj, theta = pest.theta_est()
print("The estimated parameters are:", theta)
print("The objective value is:", obj)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
# ...

# %%
# calculate the covariance matrix
cov_beta = pest.cov_est(method="finite_difference")

print("The covariance matrix is :\n", cov_beta)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
# ...

# %% [markdown]
# ## Compute the covariance matrix of the original model parameters

# %%
# derivative of a1 w.r.t. all the parameters (a1 = exp(alpha_1))
da1_dalpha_1 = np.exp(theta['alpha_1'])
da1_dalpha_2 = 0
da1_dalpha_3 = 0
da1_dE1 = 0
da1_dE2 = 0
da1_dE3 = 0
da1_dbeta = [da1_dalpha_1, da1_dalpha_2, da1_dalpha_3, da1_dE1, da1_dE2, da1_dE3]

# derivative of a2 w.r.t. all the parameters (a2 = exp(alpha_2))
da2_dalpha_1 = 0
da2_dalpha_2 = np.exp(theta['alpha_2'])
da2_dalpha_3 = 0
da2_dE1 = 0
da2_dE2 = 0
da2_dE3 = 0
da2_dbeta = [da2_dalpha_1, da2_dalpha_2, da2_dalpha_3, da2_dE1, da2_dE2, da2_dE3]

# derivative of a3 w.r.t. all the parameters (a3 = exp(alpha_3))
da3_dalpha_1 = 0
da3_dalpha_2 = 0
da3_dalpha_3 = np.exp(theta['alpha_3'])
da3_dE1 = 0
da3_dE2 = 0
da3_dE3 = 0
da3_dbeta = [da3_dalpha_1, da3_dalpha_2, da3_dalpha_3, da3_dE1, da3_dE2, da3_dE3]

# derivative of E1 w.r.t. all the parameters (E1 = E1)
dE1_dalpha_1 = 0
dE1_dalpha_2 = 0
dE1_dalpha_3 = 0
dE1_dE1 = 1
dE1_dE2 = 0
dE1_dE3 = 0
dE1_dbeta = [dE1_dalpha_1, dE1_dalpha_2, dE1_dalpha_3, dE1_dE1, dE1_dE2, dE1_dE3]

# derivative of E2 w.r.t. all the parameters (E2 = E2)
dE2_dalpha_1 = 0
dE2_dalpha_2 = 0
dE2_dalpha_3 = 0
dE2_dE1 = 0
dE2_dE2 = 1
dE2_dE3 = 0
dE2_dbeta = [dE2_dalpha_1, dE2_dalpha_2, dE2_dalpha_3, dE2_dE1, dE2_dE2, dE2_dE3]

# derivative of E3 w.r.t. all the parameters (E3 = E3)
dE3_dalpha_1 = 0
dE3_dalpha_2 = 0
dE3_dalpha_3 = 0
dE3_dE1 = 0
dE3_dE2 = 0
dE3_dE3 = 1
dE3_dbeta = [dE3_dalpha_1, dE3_dalpha_2, dE3_dalpha_3, dE3_dE1, dE3_dE2, dE3_dE3]

# Jacobian matrix
dtheta_dbeta = np.zeros((6, 6))
dtheta_dbeta[0, :] = da1_dbeta
dtheta_dbeta[1, :] = da2_dbeta
dtheta_dbeta[2, :] = da3_dbeta
dtheta_dbeta[3, :] = dE1_dbeta
dtheta_dbeta[4, :] = dE2_dbeta
dtheta_dbeta[5, :] = dE3_dbeta

# calculate the covariance matrix of the original parameters
cov_theta = dtheta_dbeta @ cov_beta @ dtheta_dbeta.T
cov_theta_df = pd.DataFrame(
                            cov_theta.to_numpy(),
                            index=["a1", "a2", "a3", "E1", "E2", "E3"],
                            columns=["a1", "a2", "a3", "E1", "E2", "E3"],)

print("Covariance matrix of the original parameters:\n",cov_theta_df)
# Out:
# Covariance matrix of the original parameters:
#                a1            a2            a3            E1            E2  \
# a1  3.438333e+17  3.323548e+20 -4.088227e+24  2.980696e+08  1.429256e+09
# a2  3.323548e+20  1.126945e+24 -1.169221e+28  2.680812e+11  4.824730e+12
# a3 -4.088227e+24 -1.169221e+28  1.229936e+32 -3.351554e+15 -5.007384e+16
# E1  2.980696e+08  2.680813e+11 -3.351555e+15  2.588953e-01  1.153391e+00
# E2  1.429256e+09  4.824730e+12 -5.007384e+16  1.153391e+00  2.065602e+01
# E3 -1.719358e+09 -4.840281e+12  5.098604e+16 -1.411457e+00 -2.073000e+01
#
#               E3
# a1 -1.719358e+09
# a2 -4.840281e+12
# a3  5.098604e+16
# E1 -1.411457e+00
# E2 -2.073000e+01
# E3  2.113879e+01
