# %%
import pyomo.environ as pyo
import math
import pandas as pd
import numpy as np
from scipy import stats
import pyomo.dae as dae
import matplotlib.pyplot as plt
from pyomo.contrib.parmest.experiment import Experiment
from pyomo.contrib.doe import DesignOfExperiments
from pyomo.contrib.parmest import parmest

# %% [markdown]
# # Modeling a lab-scale batch reactor to scale-up the Williams-Otto process

# %% [markdown]
# ## Create the functions to be used in this notebook

# %%
class BatchReactorExperiment(Experiment):
    """Creates and labels the Pyomo model of the batch reactor
    
    Parameters
    ----------
    data: Pandas dataframe or .csv file,
        Data containing the sample time and measured values of mass fractions 
    XA0: float,
        Initial mass fraction of species A
    temp_control: int, float, or dict,
        Constant or piecewise-linear profile of the reaction temperature (in R)
    const_temp: Boolean,
        Species if the batch reactor is a constant or variable temperature system
    comb_const_temp: Boolean,
        Specifies if the data for the constant low and high temperatures are combined
    doe_solve: Boolean,
        Species if the batch reactor model is being used for optimal experimental design
    sample_time: float or int,
        Time to collect a sample for mass fraction measurements

    Returns
    -------
    m: annotated Pyomo model of the batch reactor
    """

    def __init__(self, XA0, temp_control, const_temp, data=None, doe_solve=False,):

        self.data = data
        self.XA0 = XA0
        self.temp_control = temp_control
        self.const_temp = const_temp
        self.doe_solve = doe_solve
        self.model = None

    def get_labeled_model(self):
        self.create_model()
        self.label_model()

        return self.model

    def create_model(self):
        if self.const_temp and not self.doe_solve:
            self.model = reform_batch_reactor_model_const(self.XA0, self.temp_control)
        elif not self.const_temp and not self.doe_solve:
            self.model = reform_batch_reactor_model_var(self.XA0, self.temp_control)

        return self.model

    def label_model(self):

        m = self.model

        if self.doe_solve:
            # label the experimental decision variables
            m.experiment_inputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
            m.experiment_inputs[m.XA0] = None
            m.experiment_inputs[m.tf] = None

            # label the measured variables
            m.experiment_outputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
            m.experiment_outputs.update(
                (m.XA[t], None) for t in m.tau
            )
            m.experiment_outputs.update(
                (m.XB[t], None) for t in m.tau
            )
            m.experiment_outputs.update(
                (m.XC[t], None) for t in m.tau
            )
            m.experiment_outputs.update(
                (m.XP[t], None) for t in m.tau
            )
            m.experiment_outputs.update(
                (m.XE[t], None) for t in m.tau
            )
            m.experiment_outputs.update(
                (m.XG[t], None) for t in m.tau
            )
            
            # add the measurement errors
            m.measurement_error = pyo.Suffix(direction=pyo.Suffix.LOCAL)
            m.measurement_error.update(
                (m.XA[t], 0.01) for t in m.tau
            )
            m.measurement_error.update(
                (m.XB[t], 1e-04) for t in m.tau
            )
            m.measurement_error.update(
                (m.XC[t], 1e-04) for t in m.tau
            )
            m.measurement_error.update(
                (m.XP[t], 0.01) for t in m.tau
            )
            m.measurement_error.update(
                (m.XE[t], 0.01) for t in m.tau
            )
            m.measurement_error.update(
                (m.XG[t], 0.01) for t in m.tau
            )
        else:
            meas_time_points = self.data["Time (hr)"]
        
            # label the measured variables
            m.experiment_outputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
            m.experiment_outputs.update(
                (m.XA[t], self.data["XA"][ind]) for ind, t in enumerate(meas_time_points)
            )
            m.experiment_outputs.update(
                (m.XB[t], self.data["XB"][ind]) for ind, t in enumerate(meas_time_points)
            )
            m.experiment_outputs.update(
                (m.XC[t], self.data["XC"][ind]) for ind, t in enumerate(meas_time_points)
            )
            m.experiment_outputs.update(
                (m.XP[t], self.data["XP"][ind]) for ind, t in enumerate(meas_time_points)
            )
            m.experiment_outputs.update(
                (m.XE[t], self.data["XE"][ind]) for ind, t in enumerate(meas_time_points)
            )
            m.experiment_outputs.update(
                (m.XG[t], self.data["XG"][ind]) for ind, t in enumerate(meas_time_points)
            )
            
            # add the measurement errors
            m.measurement_error = pyo.Suffix(direction=pyo.Suffix.LOCAL)
            m.measurement_error.update(
                (m.XA[t], 0.01) for t in meas_time_points
            )
            m.measurement_error.update(
                (m.XB[t], 1e-06) for t in meas_time_points
            )
            m.measurement_error.update(
                (m.XC[t], 1e-06) for t in meas_time_points
            )
            m.measurement_error.update(
                (m.XP[t], 0.01) for t in meas_time_points
            )
            m.measurement_error.update(
                (m.XE[t], 0.01) for t in meas_time_points
            )
            m.measurement_error.update(
                (m.XG[t], 0.01) for t in meas_time_points
            )

        # label the unknown parameters
        m.unknown_parameters = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.unknown_parameters.update(
            (k, pyo.value(k)) for k in [m.alpha_1, m.alpha_2, m.alpha_3, m.E1, m.E2, m.E3]
        )

        return m

# %%
def get_original_parameters(reform_params):
    """
    Calculates the original parameters from the reformulated parameters

    Parameters
    ----------
    reform_params: dict,
        Estimated values of the reformulated parameters
    
    Returns
    -------
    orig_params: dict, calculated values of the original parameters
    """
    
    # get the original a1, a2, and a3 parameters
    a1 = np.exp(reform_params['alpha_1'])
    a2 = np.exp(reform_params['alpha_2'])
    a3 = np.exp(reform_params['alpha_3'])

    # create a new dictionary for the original parameters
    orig_params = {"a1":a1, "a2":a2, "a3":a3, "E1": reform_params["E1"], "E2": reform_params["E2"], "E3": reform_params["E3"]}

    return orig_params

# %%
def get_original_covariance(reform_params, cov_reform):
    """
    Computes the covariance matrix of the original parameters

    Parameters
    ----------
    reform_params: dict,
        Estimated values of the reformulated parameters
    cov_reform: Pandas.DataFrame,
        Covariance matrix of the reformulated parameters    
    
    Returns
    -------
    cov_orig_df: Pandas.DataFrame, covariance matrix of the original parameters
    """

    # derivative of a1 w.r.t. all the parameters given that a1 = exp(alpha_1)
    da1_dalpha_1 = np.exp(reform_params['alpha_1'])
    da1_dalpha_2 = 0
    da1_dalpha_3 = 0
    da1_dE1 = 0
    da1_dE2 = 0
    da1_dE3 = 0
    da1_dbeta = [da1_dalpha_1, da1_dalpha_2, da1_dalpha_3, da1_dE1, da1_dE2, da1_dE3]
    
    # derivative of a2 w.r.t. all the parameters given that a2 = exp(alpha_2)
    da2_dalpha_1 = 0
    da2_dalpha_2 = np.exp(reform_params['alpha_2'])
    da2_dalpha_3 = 0
    da2_dE1 = 0
    da2_dE2 = 0
    da2_dE3 = 0
    da2_dbeta = [da2_dalpha_1, da2_dalpha_2, da2_dalpha_3, da2_dE1, da2_dE2, da2_dE3]
    
    # derivative of a3 w.r.t. all the parameters given that a3 = exp(alpha_3)
    da3_dalpha_1 = 0
    da3_dalpha_2 = 0
    da3_dalpha_3 = np.exp(reform_params['alpha_3'])
    da3_dE1 = 0
    da3_dE2 = 0
    da3_dE3 = 0
    da3_dbeta = [da3_dalpha_1, da3_dalpha_2, da3_dalpha_3, da3_dE1, da3_dE2, da3_dE3]

    # derivative of E1 w.r.t. all the parameters given that E1 = E1
    dE1_dalpha_1 = 0
    dE1_dalpha_2 = 0
    dE1_dalpha_3 = 0
    dE1_dE1 = 1
    dE1_dE2 = 0
    dE1_dE3 = 0
    dE1_dbeta = [dE1_dalpha_1, dE1_dalpha_2, dE1_dalpha_3, dE1_dE1, dE1_dE2, dE1_dE3]
    
    # derivative of E2 w.r.t. all the parameters given that E2 = E2
    dE2_dalpha_1 = 0
    dE2_dalpha_2 = 0
    dE2_dalpha_3 = 0
    dE2_dE1 = 0
    dE2_dE2 = 1
    dE2_dE3 = 0
    dE2_dbeta = [dE2_dalpha_1, dE2_dalpha_2, dE2_dalpha_3, dE2_dE1, dE2_dE2, dE2_dE3]
    
    # derivative of E3 w.r.t. all the parameters given that E3 = E3
    dE3_dalpha_1 = 0
    dE3_dalpha_2 = 0
    dE3_dalpha_3 = 0
    dE3_dE1 = 0
    dE3_dE2 = 0
    dE3_dE3 = 1
    dE3_dbeta = [dE3_dalpha_1, dE3_dalpha_2, dE3_dalpha_3, dE3_dE1, dE3_dE2, dE3_dE3]

    # Jacobian matrix
    dtheta_dbeta = np.zeros((6, 6))
    dtheta_dbeta[0, :] = da1_dbeta
    dtheta_dbeta[1, :] = da2_dbeta
    dtheta_dbeta[2, :] = da3_dbeta
    dtheta_dbeta[3, :] = dE1_dbeta
    dtheta_dbeta[4, :] = dE2_dbeta
    dtheta_dbeta[5, :] = dE3_dbeta

    # calculate the covariance matrix of the original parameters
    cov_orig = dtheta_dbeta @ cov_reform @ dtheta_dbeta.T
    cov_orig_df = pd.DataFrame(
                                cov_orig.to_numpy(),
                                index=["a1", "a2", "a3", "E1", "E2", "E3"],
                                columns=["a1", "a2", "a3", "E1", "E2", "E3"],)

    return cov_orig_df

# %%
def parameter_covariance_est(data, XA0, temp_control=None, const_temp=True, doe_solve=False):
    """Estimates the parameters and covariance matrix of the batch reactor model from the data

    Parameters
    ----------
    data: Pandas.DataFrame or .csv file,
        Data containing the sample time and measured values of species mass fraction
    XA0: float,
        Initial mass fraction of species A
    temp_control: int, float, or dict,
        Constant or piecewise-linear profile of the reaction temperature (in R)
    const_temp: Boolean,
        Species if the batch reactor is a constant or variable temperature system
    doe_solve: Boolean,
        Species if the batch reactor model is being used for optimal experimental design

    Returns
    -------
    theta_original: dict, estimated values of the model parameters
    cov_theta_df: Pandas.DataFrame, covariance matrix of the estimated model parameters
    """

    # create a list of the experiment class
    exp_list = [BatchReactorExperiment(data=data, XA0=XA0, temp_control=temp_control, 
                                       const_temp=const_temp, doe_solve=doe_solve)]
    
    # Create the Estimator object
    pest = parmest.Estimator(exp_list, obj_function="SSE_weighted", tee=True)
    
    # Estimate the reformulated parameters
    obj, theta_reform = pest.theta_est()
    print("The reformulated parameters are:", theta_reform)

    # get the original parameters
    theta_original = get_original_parameters(theta_reform)

    # compute the covariance matrix of the reformulated parameters
    try:
        cov_reform = pest.cov_est(method="finite_difference")
        print("Covariance matrix of reformulated parameters:\n", cov_reform)

        # get the Fisher information matrix
        prior_FIM_reform = np.linalg.inv(cov_reform)
        print("\nThe prior FIM for Pyomo.DoE is:\n", prior_FIM_reform)

        # get the covariance matrix of the original parameters
        cov_original = get_original_covariance(theta_reform, cov_reform)

        return obj, theta_original, cov_original
    except RuntimeError:
        return obj, theta_original, ["N/A"]

# %%
def ground_truth_data(measured_var):
    """Creates a Pandas dataframe for ground-truth simulation of mass fractions

    Parameters
    ----------
    measured_var: 2D numpy array or matrix,
        matrix containing ground-truth simulation of mass fractions

    Returns
    -------
    outputs: Pandas dataframe containing ground-truth simulation of mass fractions 
    """
    
    # name of experimental outputs
    output_names = ["XA", "XB", "XC", "XP", "XE", "XG"]
    
    # outputs dataframe
    outputs = pd.DataFrame(measured_var, columns=output_names)
    
    print("\nOutput variables:\n",outputs)

    return outputs

def generate_noisy_measurement(mass_frac, mass_frac_std):
    """Generates noisy measurement of mass fractions

    Parameters
    ----------
    mass_frac: Pandas series or list,
        A list or Pandas series containing mass fractions
    mass_frac_std: float,
        Standard deviation of the mass fraction measurement errors

    Returns
    -------
    noisy_mass_frac: A list containing noisy measurement of mass fractions
    """
    
    # generate gaussian noise
    np.random.seed(10)
    noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(mass_frac))
    
    # corrupt the mass fraction with the noise
    noisy_mass_frac = mass_frac + noise
    
    return noisy_mass_frac

def synthetic_data_compiler(data_matrix, csv_name):
    """Generates noisy measurement of mass fractions

    Parameters
    ----------
    data_matrix: 2D numpy array or matrix,
        matrix containing the noisy measurement of mass fractions 
    csv_name: str,
        Csv file name

    Returns
    -------
    data: Pandas dataframe containing the generated data
    """
    # data columns
    column_names = ["Time (hr)", "XA", "XB", "XC", "XP", "XE", "XG"]
    
    # number of data columns
    n_columns = len(column_names)
    
    # full data
    data = pd.DataFrame(data_matrix, columns=column_names)
    print("Generated data:\n",data)
    
    data.to_csv(f"{csv_name}.csv", index=False)

    return data

# %% [markdown]
# ## Modeling the batch reactor using a constant temperature profile

# %%
def batch_reactor_model_const(XA0, temp, meas_sample_time):
    """
    Creates a constant temperature Pyomo model for the batch reactor

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    temp: int or float,
        Constant reaction temperature in R
    meas_sample_time: list,
        Timepoints (in hr) to collect samples for mass fraction measurements

    Returns
    -------
    measured_variables: list containing the mass fraction of all species at the sample timepoints
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
    model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
    model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
    model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
    model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
    model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=1-XA0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.0)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.0)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.0)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.0)

    # add the temperature variables
    model.T_reparam = pyo.Var(bounds=(0, 1))
    model.T_reparam.fix(1/temp)

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
    model.k = pyo.Var(reaction_number, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i):
        if i == 1:
            return m.k_reparam[i] == pyo.log(m.a1) - m.E1 * m.T_reparam
        elif i == 2:
            return m.k_reparam[i] == pyo.log(m.a2) - m.E2 * m.T_reparam
        else:
            return m.k_reparam[i] == pyo.log(m.a3) - m.E3 * m.T_reparam
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i):
        return m.k[i] == pyo.exp(m.k_reparam[i])
    
    model.k_eq = pyo.Constraint(
        reaction_number, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        return m.dXA[t] == - m.r[1, t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        return m.dXE[t] == 2 * m.r[2, t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        return m.dXG[t] == 1.5 * m.r[3, t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA[t0].fix(XA0)
    model.XB[t0].fix(1 - XA0)
    model.XC[t0].fix(0.0)
    model.XE[t0].fix(0.0)
    model.XG[t0].fix(0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)

    # get the mass fraction of all species
    time = [t for t in model.t]
    print("The timepoints are:",time)
    XA_values = [pyo.value(model.XA[t]) for t in model.t]
    XB_values = [pyo.value(model.XB[t]) for t in model.t] 
    XC_values = [pyo.value(model.XC[t]) for t in model.t] 
    XP_values = [pyo.value(model.XP[t]) for t in model.t] 
    XE_values = [pyo.value(model.XE[t]) for t in model.t] 
    XG_values = [pyo.value(model.XG[t]) for t in model.t] 
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(time, XA_values, label='$\mathrm{X_{A}}$')
    plt.plot(time, XB_values, label='$\mathrm{X_{B}}$')
    plt.plot(time, XC_values, label='$\mathrm{X_{C}}$')
    plt.plot(time, XP_values, label='$\mathrm{X_{P}}$')
    plt.plot(time, XE_values, label='$\mathrm{X_{E}}$')
    plt.plot(time, XG_values, label='$\mathrm{X_{G}}$')
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
    # plt.savefig("batch_reactor_const_temp.png")
    plt.show()

    # store the mass fraction of all species at the sample time
    measured_variables = []
    for sample_time in meas_sample_time:
        measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
                                   pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

    print("Mass fraction of species at the sample time:",measured_variables)
    return measured_variables

# %%
# define the constant temperature and sample time for mass fraction measurements
high_const_temp = 6.8
sample_time_high_temp = [0.5, 1.5, 3]

# get the ground-truth simulation of the mass fractions
measured_var_high_temp = batch_reactor_model_const(0.4, high_const_temp, sample_time_high_temp)

# make a dataframe of the measured variables
outputs_df_high_temp = ground_truth_data(measured_var_high_temp)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2782
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      543
#
# Total number of variables............................:      855
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:      361
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      855
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 7.38e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00
# 0  0.026566  0.010858  0.000712  0.058338  0.431417  0.472110
# 1  0.017298  0.000875  0.000049  0.050169  0.432847  0.498762
# 2  0.016469  0.000040  0.000002  0.049329  0.432859  0.501300

# %% [markdown]
# ### Add Gaussian noise to the ground-truth simulations

# %%
# define the standard deviation of the mass fraction measurement errors
mass_frac_std = 0.01
B_C_mass_frac_std = 1e-06

# generate noisy mass fraction measurements
A_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XA"], mass_frac_std)
B_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XP"], mass_frac_std)
E_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XE"], mass_frac_std)
G_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XG"], mass_frac_std)

# get the number of time samples
n_samples = len(sample_time_high_temp)

# define a matrix that contains the sample time and mass fractions
data_matrix_high = np.zeros((n_samples, 7))
data_matrix_high[:, 0] = sample_time_high_temp
data_matrix_high[:, 1] = A_noisy_mass_fraction_high
data_matrix_high[:, 2] = B_noisy_mass_fraction_high
data_matrix_high[:, 3] = C_noisy_mass_fraction_high
data_matrix_high[:, 4] = P_noisy_mass_fraction_high
data_matrix_high[:, 5] = E_noisy_mass_fraction_high
data_matrix_high[:, 6] = G_noisy_mass_fraction_high

# %% [markdown]
# ### Compile the generated data into a csv file

# %%
data_high_temp = synthetic_data_compiler(data_matrix_high, "batch_reactor_const_temp")
# Out:
# Generated data:
#     Time (hr)        XA        XB            XC        XP        XE        XG
# 0        0.5  0.039882  0.010859  7.130752e-04  0.071654  0.444732  0.485426
# 1        1.5  0.024451  0.000875  4.954773e-05  0.057322  0.440000  0.505915
# 2        3.0  0.001015  0.000038  6.317955e-07  0.033875  0.417405  0.485846

# %% [markdown]
# ### Reformulate the batch reactor model for parameter estimation

# %%
def reform_batch_reactor_model_const(XA0, temp):
    """
    Reformulates the constant temperature batch reactor model for parameter estimation

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    temp: int or float,
        Constant reaction temperature in R

    Returns
    -------
    model: Pyomo model of the batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=1-XA0-4e-6)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)

    # add the temperature variables
    model.T_reparam = pyo.Var(bounds=(0, 1))
    model.T_reparam.fix(1/temp)

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
    model.k = pyo.Var(reaction_number, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i):
        if i == 1:
            return m.k_reparam[i] == model.alpha_1 - m.E1 * m.T_reparam
        elif i == 2:
            return m.k_reparam[i] == model.alpha_2 - m.E2 * m.T_reparam
        else:
            return m.k_reparam[i] == model.alpha_3 - m.E3 * m.T_reparam
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i):
        return m.k[i] == pyo.exp(m.k_reparam[i])
    
    model.k_eq = pyo.Constraint(
        reaction_number, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        return m.dXA[t] == - m.k[1] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        return m.dXB[t] == - (m.k[1] * m.XA[t] * m.XB[t] + m.k[2] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        return m.dXC[t] == 2 * m.k[1] * m.XA[t] * m.XB[t] - 2 * m.k[2] * m.XB[t] * m.XC[t] - m.k[3] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        return m.dXE[t] == 2 * m.k[2] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        return m.dXG[t] == 1.5 * m.k[3] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == 1 - XA0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %%
obj_high, estimated_params_high, cov_matrix_high = parameter_covariance_est(data_high_temp, XA0=0.4, 
                                                                            temp_control=high_const_temp,)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3604
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      866
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.64e+00 1.25e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.61e+00 1.23e+00  -1.0 3.10e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 2.60e+00 2.50e+01  -1.0 2.38e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.17e+00 1.72e+02  -1.0 3.54e+00    -  3.93e-03 5.62e-01f  1
#    4  0.0000000e+00 8.97e-01 5.56e+01  -1.0 1.63e+00    -  8.66e-02 8.87e-01f  1
#    5  0.0000000e+00 4.49e-01 9.22e+01  -1.0 6.51e-01   2.0 4.82e-01 6.27e-01h  1
#    6  0.0000000e+00 2.83e-02 5.56e+03  -1.0 2.21e-01   1.5 9.94e-01 9.90e-01h  1
#    7  0.0000000e+00 1.75e-02 2.86e+04  -1.0 2.33e-01   1.0 4.62e-01 9.95e-01h  1
#    8  0.0000000e+00 4.77e-01 2.83e+06  -1.0 3.43e+01    -  4.58e-01 1.00e+00f  1
#    9  0.0000000e+00 4.40e-03 4.74e+05  -1.0 4.49e-01   0.6 9.43e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 4.04e-01 4.56e+05  -1.0 8.66e+01    -  7.49e-01 1.00e+00f  1
#   11  0.0000000e+00 8.00e-01 4.85e+04  -1.0 3.50e+02    -  8.94e-01 1.00e+00f  1
#   12  0.0000000e+00 1.21e-02 3.60e+04  -1.0 3.20e+03    -  2.57e-01 1.00e+00f  1
#   13  0.0000000e+00 9.24e-04 1.30e+04  -1.0 4.26e+03    -  6.38e-01 1.00e+00f  1
#   14  0.0000000e+00 1.14e-05 5.14e+03  -1.0 1.10e+04    -  6.06e-01 1.00e+00f  1
#   15  0.0000000e+00 9.80e-10 1.82e+03  -1.0 2.36e+04    -  6.47e-01 1.00e+00f  1
#   16  0.0000000e+00 6.13e-10 4.71e+02  -1.0 4.43e+04    -  7.40e-01 1.00e+00f  1
#   17  0.0000000e+00 3.64e-12 6.28e+04  -1.7 1.18e+04    -  9.92e-01 1.00e+00f  1
#   18  0.0000000e+00 9.51e-12 2.00e-07  -1.7 7.61e+04    -  1.00e+00 1.00e+00f  1
#   19  0.0000000e+00 2.66e-15 7.86e-05  -5.7 3.74e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20
#   26  1.2041203e+01 3.29e-07 9.47e-08  -8.6 3.49e-02    -  1.00e+00 1.00e+00h  1
#   27  1.2041203e+01 3.64e-12 2.51e-14  -8.6 1.65e-06    -  1.00e+00 1.00e+00h  1
#   28  1.2039358e+01 4.86e-07 3.86e-03 -12.9 2.79e-02    -  1.00e+00 1.00e+00h  1
#   29  1.2039358e+01 3.64e-12 2.52e-15 -12.9 5.97e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 29
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2039358386944539e-07    1.2039358386944539e+01
# Dual infeasibility......:   2.5162933220732557e-15    2.5162933220732555e-07
# Constraint violation....:   3.6379788070917130e-12    3.6379788070917130e-12
# Complementarity.........:   1.2544303101429119e-13    1.2544303101429118e-05
# Overall NLP error.......:   3.6379788070917130e-12    1.2544303101429118e-05
#
#
# Number of objective function evaluations             = 30
# Number of objective gradient evaluations             = 30
# Number of equality constraint evaluations            = 30
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 30
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 29
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.108
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# The reformulated parameters are: alpha_1     25643.457835
# alpha_2     25644.288256
# alpha_3     25644.721241
# E1         174342.438578
# E2         174336.794220
# E3         174333.851523
# dtype: float64
# C:\Users\lilon\AppData\Local\Temp\ipykernel_55832\1011479802.py:16: RuntimeWarning: overflow encountered in exp
#   a1 = np.exp(reform_params['alpha_1'])
# C:\Users\lilon\AppData\Local\Temp\ipykernel_55832\1011479802.py:17: RuntimeWarning: overflow encountered in exp
#   a2 = np.exp(reform_params['alpha_2'])
# C:\Users\lilon\AppData\Local\Temp\ipykernel_55832\1011479802.py:18: RuntimeWarning: overflow encountered in exp
#   a3 = np.exp(reform_params['alpha_3'])
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3604
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      866
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.64e+00 1.25e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.61e+00 1.23e+00  -1.0 3.10e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 2.60e+00 2.50e+01  -1.0 2.38e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.17e+00 1.72e+02  -1.0 3.54e+00    -  3.93e-03 5.62e-01f  1
#    4  0.0000000e+00 8.97e-01 5.56e+01  -1.0 1.63e+00    -  8.66e-02 8.87e-01f  1
#    5  0.0000000e+00 4.49e-01 9.22e+01  -1.0 6.51e-01   2.0 4.82e-01 6.27e-01h  1
#    6  0.0000000e+00 2.83e-02 5.56e+03  -1.0 2.21e-01   1.5 9.94e-01 9.90e-01h  1
#    7  0.0000000e+00 1.75e-02 2.86e+04  -1.0 2.33e-01   1.0 4.62e-01 9.95e-01h  1
#    8  0.0000000e+00 4.77e-01 2.83e+06  -1.0 3.43e+01    -  4.58e-01 1.00e+00f  1
#    9  0.0000000e+00 4.40e-03 4.74e+05  -1.0 4.49e-01   0.6 9.43e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10
# In iteration 662, 1 Slack too small, adjusting variable bound
#  663r 0.0000000e+00 1.32e+02 9.94e+06  -9.0 4.88e+05    -  3.44e-03 4.55e-04f  1
# In iteration 663, 1 Slack too small, adjusting variable bound
#  664r 0.0000000e+00 1.32e+02 1.05e+07  -9.0 2.27e+05    -  3.48e-03 5.07e-04f  1
# In iteration 664, 1 Slack too small, adjusting variable bound
#  665r 0.0000000e+00 1.34e+02 1.39e+07  -9.0 2.00e+05    -  2.50e-02 1.56e-03f  1
# In iteration 665, 1 Slack too small, adjusting variable bound
#  666r 0.0000000e+00 1.52e+02 1.32e+07  -9.0 1.26e+05    -  1.19e-09 7.47e-03f  1
# In iteration 666, 1 Slack too small, adjusting variable bound
#  667r 0.0000000e+00 1.50e+02 1.24e+07  -9.0 1.84e+04    -  6.82e-02 7.50e-03f  1
# In iteration 667, 1 Slack too small, adjusting variable bound
#  668r 0.0000000e+00 1.50e+02 1.24e+07  -9.0 2.04e+04    -  1.09e-04 3.65e-04f  1
# In iteration 668, 1 Slack too small, adjusting variable bound
#  669r 0.0000000e+00 1.39e+02 1.17e+07  -9.0 2.04e+04    -  2.22e-02 5.44e-02f  1
# In iteration 669, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  670r 0.0000000e+00 1.33e+02 1.13e+07  -9.0 2.03e+04    -  4.85e-02 3.50e-02f  1
# In iteration 670, 1 Slack too small, adjusting variable bound
#  671r 0.0000000e+00 1.13e+02 1.17e+07  -9.0 2.00e+04    -  8.56e-01 1.03e-01f  1
# In iteration 671, 1 Slack too small, adjusting variable bound
#  672r 0.0000000e+00 1.13e+02 1.31e+07  -9.0 2.15e+04    -  4.18e-01 5.87e-09h  1
# In iteration 672, 1 Slack too small, adjusting variable bound
#  673r 0.0000000e+00 1.06e+02 1.21e+07  -9.0 2.07e+04    -  1.36e-09 6.85e-02f  1
# In iteration 673, 1 Slack too small, adjusting variable bound
#  674r 0.0000000e+00 1.06e+02 1.28e+07  -9.0 1.94e+04    -  4.91e-01 1.92e-03f  1
# In iteration 674, 1 Slack too small, adjusting variable bound
#  675r 0.0000000e+00 1.06e+02 1.27e+07  -9.0 1.98e+04    -  3.02e-02 5.73e-05h  1
# In iteration 675, 1 Slack too small, adjusting variable bound
#  676r 0.0000000e+00 1.05e+02 1.14e+07  -9.0 2.11e+04    -  9.19e-02 8.55e-03f  1
# In iteration 676, 1 Slack too small, adjusting variable bound
#  677r 0.0000000e+00 6.55e+02 1.07e+07  -9.0 2.11e+04    -  1.36e-01 3.72e-01f  1
# In iteration 677, 1 Slack too small, adjusting variable bound
#  678r 0.0000000e+00 6.02e+02 3.41e+06  -9.0 1.62e+04    -  6.48e-01 1.38e-01f  1
#  679r 0.0000000e+00 6.00e+02 3.39e+06  -9.0 1.40e+04    -  3.15e-09 2.99e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  680r 0.0000000e+00 6.00e+02 3.39e+06  -9.0 1.38e+04    -  2.01e-01 4.24e-05h  1
#  681r 0.0000000e+00 5.99e+02 3.38e+06  -9.0 1.38e+04    -  2.19e-03 2.00e-03h  1
#  682r 0.0000000e+00 5.81e+02 3.27e+06  -9.0 1.38e+04    -  2.54e-01 3.27e-02f  1
#  683r 0.0000000e+00 5.63e+02 3.16e+06  -9.0 1.34e+04    -  3.73e-02 3.26e-02f  1
#  684r 0.0000000e+00 5.60e+02 3.14e+06  -9.0 1.30e+04    -  3.32e-02 5.87e-03h  1
#  685r 0.0000000e+00 5.43e+02 3.04e+06  -9.0 1.30e+04    -  3.58e-01 3.25e-02f  1
#  686r 0.0000000e+00 5.26e+02 2.94e+06  -9.0 1.26e+04    -  7.85e-02 3.30e-02f  1
#  687r 0.0000000e+00 5.21e+02 2.91e+06  -9.0 1.23e+04    -  1.18e-02 1.04e-02h  1
#  688r 0.0000000e+00 4.58e+02 2.29e+06  -9.0 1.22e+04    -  1.12e-01 2.04e-01f  1
#  689r 0.0000000e+00 4.49e+02 2.24e+06  -9.0 1.01e+04    -  1.00e-01 1.95e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  690r 0.0000000e+00 3.99e+02 1.92e+06  -9.0 9.89e+03    -  1.81e-01 1.39e-01f  1
#  691r 0.0000000e+00 3.86e+02 1.85e+06  -9.0 8.67e+03    -  1.31e-01 3.42e-02h  1
#  692r 0.0000000e+00 3.13e+02 7.67e+05  -9.0 8.40e+03    -  1.71e-01 5.44e-01f  1
#  693r 0.0000000e+00 1.26e+02 1.19e+05  -9.0 4.16e+03    -  6.53e-01 8.05e-01h  1
#  694r 0.0000000e+00 1.92e+01 3.02e+02  -9.0 8.92e+02    -  1.00e+00 9.91e-01h  1
#  695r 0.0000000e+00 1.92e+01 3.94e-02  -9.0 1.09e+01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 695
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.0628819516549832e-02    1.0628819516549832e-02
# Constraint violation....:   1.9228940319829427e+01    1.9228940319829427e+01
# Complementarity.........:   9.0914578806282104e-10    9.0914578806282104e-10
# Overall NLP error.......:   1.9228940319829427e+01    1.9228940319829427e+01
#
#
# Number of objective function evaluations             = 980
# Number of objective gradient evaluations             = 8
# Number of equality constraint evaluations            = 984
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 702
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 696
# Total CPU secs in IPOPT (w/o function evaluations)   =     12.057
# Total CPU secs in NLP function evaluations           =      0.651
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %%
print("Estimates of the original parameters:\n",estimated_params_high)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_high)
# Out:
# Estimates of the original parameters:
#  {'a1': inf, 'a2': inf, 'a3': inf, 'E1': 174342.43857764782, 'E2': 174336.79422028246, 'E3': 174333.85152302973}
#
# Covariance matrix of the original parameters:
#  ['N/A']

# %% [markdown]
# ### Low temperature constant batch reactor

# %%
# define the constant temperature and sample time for mass fraction measurements
low_const_temp = 5.8
sample_time_low_temp = [0.5, 1.5, 3]

# get the ground-truth simulation of the mass fractions
measured_var_low_temp = batch_reactor_model_const(0.4, low_const_temp, sample_time_low_temp)

# make a dataframe of the measured variables
outputs_df_low_temp = ground_truth_data(measured_var_low_temp)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.6151655237112723e-09    3.6151655237112723e-09
#
#
# Number of objective function evaluations             = 30
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 30
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 27
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 25
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.119
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# The timepoints are: [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55, 1.6, 1.65, 1.7, 1.75, 1.8, 1.85, 1.9, 1.95, 2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85, 2.9, 2.95, 3]
# Mass fraction of species at the sample time: [[0.16163863212810503, 0.17649914685818743, 0.06286243822375227, 0.16334882055838085, 0.37027897026054857, 0.06537199178284317], [0.0926820779107295, 0.05173636581531228, 0.022318695363970704, 0.18573284953792038, 0.4818914223424412, 0.16563858900211736], [0.06991210422970037, 0.018568852684588362, 0.008728687591812452, 0.17696295367402728, 0.5026864979040768, 0.2231409038297017]]
#
# Output variables:
#           XA        XB        XC        XP        XE        XG
# 0  0.161639  0.176499  0.062862  0.163349  0.370279  0.065372
# 1  0.092682  0.051736  0.022319  0.185733  0.481891  0.165639
# 2  0.069912  0.018569  0.008729  0.176963  0.502686  0.223141

# %%
# generate noisy mass fraction measurements
A_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XA"], mass_frac_std)
B_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XP"], mass_frac_std)
E_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XE"], mass_frac_std)
G_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XG"], mass_frac_std)

# define a matrix that contains the sample time and mass fractions
data_matrix_low = np.zeros((n_samples, 7))
data_matrix_low[:, 0] = sample_time_low_temp
data_matrix_low[:, 1] = A_noisy_mass_fraction_low
data_matrix_low[:, 2] = B_noisy_mass_fraction_low
data_matrix_low[:, 3] = C_noisy_mass_fraction_low
data_matrix_low[:, 4] = P_noisy_mass_fraction_low
data_matrix_low[:, 5] = E_noisy_mass_fraction_low
data_matrix_low[:, 6] = G_noisy_mass_fraction_low

# compile the generated data into a csv file
data_low_temp = synthetic_data_compiler(data_matrix_low, "batch_reactor_const_temp_low")
# Out:
# Generated data:
#     Time (hr)        XA        XB        XC        XP        XE        XG
# 0        0.5  0.174954  0.176500  0.062864  0.176665  0.383595  0.078688
# 1        1.5  0.099835  0.051737  0.022319  0.192886  0.489044  0.172791
# 2        3.0  0.054458  0.018567  0.008727  0.161509  0.487232  0.207687

# %%
# estimate the parameters
obj_low, estimated_params_low, cov_matrix_low = parameter_covariance_est(data_low_temp, XA0=0.4, 
                                                                         temp_control=low_const_temp,)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 24
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 23
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.100
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3598
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      860
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
# ...
# In iteration 813, 1 Slack too small, adjusting variable bound
#  814r 0.0000000e+00 4.46e+01 1.01e+05  -9.0 4.70e+03    -  2.43e-01 4.03e-02f  1
# In iteration 814, 1 Slack too small, adjusting variable bound
#  815r 0.0000000e+00 4.45e+01 1.01e+05  -9.0 4.29e+03    -  3.70e-02 1.85e-04h  1
# In iteration 815, 1 Slack too small, adjusting variable bound
#  816r 0.0000000e+00 4.36e+01 9.85e+04  -9.0 4.29e+03    -  4.49e-02 2.69e-02f  1
# In iteration 816, 1 Slack too small, adjusting variable bound
#  817r 0.0000000e+00 4.18e+01 8.72e+04  -9.0 4.08e+03    -  3.60e-02 1.11e-01f  1
# In iteration 817, 1 Slack too small, adjusting variable bound
#  818r 0.0000000e+00 3.94e+01 7.90e+04  -9.0 3.40e+03    -  2.14e-02 9.13e-02f  1
# In iteration 818, 1 Slack too small, adjusting variable bound
#  819r 0.0000000e+00 3.67e+01 6.99e+04  -9.0 3.01e+03    -  3.12e-02 1.13e-01f  1
# In iteration 819, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  820r 0.0000000e+00 3.57e+01 6.78e+04  -9.0 2.62e+03    -  1.20e-01 2.96e-02f  1
# In iteration 820, 1 Slack too small, adjusting variable bound
#  821r 0.0000000e+00 3.57e+01 6.78e+04  -9.0 2.85e+03    -  2.90e-02 6.84e-05h  1
# In iteration 821, 1 Slack too small, adjusting variable bound
#  822r 0.0000000e+00 3.48e+01 6.61e+04  -9.0 2.89e+03    -  1.48e-01 2.54e-02f  1
# In iteration 822, 1 Slack too small, adjusting variable bound
#  823r 0.0000000e+00 3.39e+01 6.42e+04  -9.0 2.41e+03    -  4.21e-02 2.84e-02f  1
# In iteration 823, 1 Slack too small, adjusting variable bound
#  824r 0.0000000e+00 3.33e+01 6.29e+04  -9.0 2.50e+03    -  4.52e-02 2.00e-02f  1
# In iteration 824, 1 Slack too small, adjusting variable bound
#  825r 0.0000000e+00 3.21e+01 6.05e+04  -9.0 2.37e+03    -  2.50e-02 3.80e-02f  1
# In iteration 825, 1 Slack too small, adjusting variable bound
#  826r 0.0000000e+00 3.15e+01 5.93e+04  -9.0 2.27e+03    -  4.94e-02 1.94e-02f  1
# In iteration 826, 1 Slack too small, adjusting variable bound
#  827r 0.0000000e+00 3.06e+01 5.73e+04  -9.0 2.22e+03    -  3.49e-02 3.36e-02f  1
# In iteration 827, 1 Slack too small, adjusting variable bound
#  828r 0.0000000e+00 2.96e+01 5.55e+04  -9.0 2.14e+03    -  4.83e-02 3.21e-02f  1
# In iteration 828, 1 Slack too small, adjusting variable bound
#  829r 0.0000000e+00 2.92e+01 5.47e+04  -9.0 2.07e+03    -  4.10e-02 1.40e-02f  1
# In iteration 829, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  830r 0.0000000e+00 2.86e+01 5.34e+04  -9.0 2.04e+03    -  1.08e-01 2.31e-02f  1
# In iteration 830, 1 Slack too small, adjusting variable bound
#  831r 0.0000000e+00 2.68e+01 4.95e+04  -9.0 1.99e+03    -  1.04e-01 7.26e-02f  1
# In iteration 831, 1 Slack too small, adjusting variable bound
#  832r 0.0000000e+00 2.66e+01 4.91e+04  -9.0 1.84e+03    -  5.98e-03 7.96e-03h  1
# In iteration 832, 1 Slack too small, adjusting variable bound
#  833r 0.0000000e+00 2.66e+01 4.91e+04  -9.0 2.14e+03    -  1.15e-02 3.00e-04h  1
# In iteration 833, 1 Slack too small, adjusting variable bound
#  834r 0.0000000e+00 2.63e+01 4.85e+04  -9.0 2.13e+03    -  7.56e-04 1.17e-02f  1
# In iteration 834, 1 Slack too small, adjusting variable bound
#  835r 0.0000000e+00 2.54e+01 4.68e+04  -9.0 2.10e+03    -  1.74e-02 3.56e-02f  1
# In iteration 835, 1 Slack too small, adjusting variable bound
#  836r 0.0000000e+00 2.44e+01 4.46e+04  -9.0 1.99e+03    -  6.32e-02 4.68e-02f  1
# In iteration 836, 1 Slack too small, adjusting variable bound
#  837r 0.0000000e+00 2.42e+01 4.42e+04  -9.0 1.63e+03    -  5.36e-02 7.77e-03h  1
# In iteration 837, 1 Slack too small, adjusting variable bound
#  838r 0.0000000e+00 2.40e+01 4.40e+04  -9.0 1.62e+03    -  3.91e-02 5.81e-03h  1
# In iteration 838, 1 Slack too small, adjusting variable bound
#  839r 0.0000000e+00 2.26e+01 4.10e+04  -9.0 1.61e+03    -  1.26e-01 6.69e-02f  1
# In iteration 839, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  840r 0.0000000e+00 2.11e+01 3.81e+04  -9.0 1.50e+03    -  5.76e-02 7.10e-02f  1
# In iteration 840, 1 Slack too small, adjusting variable bound
#  841r 0.0000000e+00 2.08e+01 3.61e+04  -9.0 1.39e+03    -  2.01e-02 5.32e-02f  1
# In iteration 841, 1 Slack too small, adjusting variable bound
#  842r 0.0000000e+00 2.08e+01 3.61e+04  -9.0 1.55e+03    -  8.65e-03 8.99e-05h  1
# In iteration 842, 1 Slack too small, adjusting variable bound
#  843r 0.0000000e+00 2.08e+01 3.58e+04  -9.0 1.57e+03    -  1.12e-03 7.95e-03h  1
# In iteration 843, 1 Slack too small, adjusting variable bound
#  844r 0.0000000e+00 2.08e+01 3.48e+04  -9.0 1.55e+03    -  1.34e-02 2.69e-02f  1
# In iteration 844, 1 Slack too small, adjusting variable bound
#  845r 0.0000000e+00 2.08e+01 3.47e+04  -9.0 1.50e+03    -  3.40e-02 3.22e-03h  1
# In iteration 845, 1 Slack too small, adjusting variable bound
#  846r 0.0000000e+00 2.08e+01 3.45e+04  -9.0 1.27e+03    -  3.38e-02 6.67e-03h  1
# In iteration 846, 1 Slack too small, adjusting variable bound
#  847r 0.0000000e+00 2.08e+01 3.28e+04  -9.0 1.26e+03    -  6.81e-03 4.95e-02f  1
# In iteration 847, 1 Slack too small, adjusting variable bound
#  848r 0.0000000e+00 2.08e+01 3.19e+04  -9.0 1.19e+03    -  3.81e-02 2.68e-02f  1
# In iteration 848, 1 Slack too small, adjusting variable bound
#  849r 0.0000000e+00 2.08e+01 3.07e+04  -9.0 1.16e+03    -  8.14e-02 3.81e-02f  1
# In iteration 849, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  850r 0.0000000e+00 2.08e+01 2.96e+04  -9.0 1.12e+03    -  4.04e-02 3.55e-02f  1
# In iteration 850, 1 Slack too small, adjusting variable bound
#  851r 0.0000000e+00 2.08e+01 2.81e+04  -9.0 1.08e+03    -  6.41e-02 4.79e-02f  1
# In iteration 851, 1 Slack too small, adjusting variable bound
#  852r 0.0000000e+00 2.08e+01 2.81e+04  -9.0 1.12e+03    -  2.91e-02 7.25e-05h  1
# In iteration 852, 1 Slack too small, adjusting variable bound
#  853r 0.0000000e+00 2.08e+01 2.77e+04  -9.0 1.20e+03    -  1.47e-03 1.54e-02h  1
# In iteration 853, 1 Slack too small, adjusting variable bound
#  854r 0.0000000e+00 2.08e+01 2.73e+04  -9.0 1.18e+03    -  1.31e-02 1.64e-02h  1
# In iteration 854, 1 Slack too small, adjusting variable bound
#  855r 0.0000000e+00 2.08e+01 2.58e+04  -9.0 1.14e+03    -  1.54e-02 5.42e-02f  1
# In iteration 855, 1 Slack too small, adjusting variable bound
#  856r 0.0000000e+00 2.08e+01 2.54e+04  -9.0 9.84e+02    -  8.92e-03 1.45e-02h  1
# In iteration 856, 1 Slack too small, adjusting variable bound
#  857r 0.0000000e+00 2.08e+01 2.51e+04  -9.0 9.17e+02    -  2.74e-02 1.11e-02h  1
# In iteration 857, 1 Slack too small, adjusting variable bound
#  858r 0.0000000e+00 2.08e+01 2.15e+04  -9.0 9.06e+02    -  4.85e-02 1.44e-01f  1
# In iteration 858, 1 Slack too small, adjusting variable bound
#  859r 0.0000000e+00 2.08e+01 2.15e+04  -9.0 7.77e+02    -  1.18e-01 3.94e-04h  1
# In iteration 859, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  860r 0.0000000e+00 2.08e+01 2.14e+04  -9.0 8.85e+02    -  7.14e-03 1.81e-03h  1
# In iteration 860, 1 Slack too small, adjusting variable bound
#  861r 0.0000000e+00 2.08e+01 2.12e+04  -9.0 8.84e+02    -  1.01e-03 1.12e-02h  1
# In iteration 861, 1 Slack too small, adjusting variable bound
#  862r 0.0000000e+00 2.08e+01 1.99e+04  -9.0 8.69e+02    -  8.90e-03 6.02e-02f  1
# In iteration 862, 1 Slack too small, adjusting variable bound
#  863r 0.0000000e+00 2.08e+01 1.97e+04  -9.0 7.89e+02    -  3.21e-02 9.82e-03h  1
# In iteration 863, 1 Slack too small, adjusting variable bound
#  864r 0.0000000e+00 2.08e+01 1.94e+04  -9.0 7.08e+02    -  3.25e-02 1.41e-02h  1
# In iteration 864, 1 Slack too small, adjusting variable bound
#  865r 0.0000000e+00 2.08e+01 1.94e+04  -9.0 6.98e+02    -  3.90e-02 9.33e-05h  1
# In iteration 865, 1 Slack too small, adjusting variable bound
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 941
# Total CPU secs in IPOPT (w/o function evaluations)   =      7.741
# Total CPU secs in NLP function evaluations           =      0.316
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %%
print("Estimates of the original parameters:\n",estimated_params_low)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_low)
# Out:
# Estimates of the original parameters:
#  {'a1': inf, 'a2': inf, 'a3': inf, 'E1': 170582.9537780548, 'E2': 170580.33899751873, 'E3': 170581.50560031968}
#
# Covariance matrix of the original parameters:
#  ['N/A']

# %% [markdown]
# ### Parameter estimation for combined low and high temperature data

# %%
# create an experiment class for the high temperature data
exp_high = BatchReactorExperiment(
    data=data_high_temp, XA0=0.4,
    temp_control=high_const_temp,
    const_temp=True,
)

# create an experiment class for the low temperature data
exp_low = BatchReactorExperiment(
    data=data_low_temp, XA0=0.4,
    temp_control=low_const_temp,
    const_temp=True,
)

# combine the high and low temperature data
exp_list_comb = [exp_high, exp_low]

# %%
# estimate the model parameters using the combined dataset
pest_comb = parmest.Estimator(exp_list_comb, obj_function="SSE_weighted", tee=True)
obj_comb, theta_comb = pest_comb.theta_est()
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3604
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      866
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.64e+00 1.25e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.61e+00 1.23e+00  -1.0 3.10e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 2.60e+00 2.50e+01  -1.0 2.38e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.17e+00 1.72e+02  -1.0 3.54e+00    -  3.93e-03 5.62e-01f  1
#    4  0.0000000e+00 8.97e-01 5.56e+01  -1.0 1.63e+00    -  8.66e-02 8.87e-01f  1
#    5  0.0000000e+00 4.49e-01 9.22e+01  -1.0 6.51e-01   2.0 4.82e-01 6.27e-01h  1
#    6  0.0000000e+00 2.83e-02 5.56e+03  -1.0 2.21e-01   1.5 9.94e-01 9.90e-01h  1
#    7  0.0000000e+00 1.75e-02 2.86e+04  -1.0 2.33e-01   1.0 4.62e-01 9.95e-01h  1
#    8  0.0000000e+00 4.77e-01 2.83e+06  -1.0 3.43e+01    -  4.58e-01 1.00e+00f  1
#    9  0.0000000e+00 4.40e-03 4.74e+05  -1.0 4.49e-01   0.6 9.43e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 4.04e-01 4.56e+05  -1.0 8.66e+01    -  7.49e-01 1.00e+00f  1
#   11  0.0000000e+00 8.00e-01 4.85e+04  -1.0 3.50e+02    -  8.94e-01 1.00e+00f  1
#   12  0.0000000e+00 1.21e-02 3.60e+04  -1.0 3.20e+03    -  2.57e-01 1.00e+00f  1
#   13  0.0000000e+00 9.24e-04 1.30e+04  -1.0 4.26e+03    -  6.38e-01 1.00e+00f  1
#   14  0.0000000e+00 1.14e-05 5.14e+03  -1.0 1.10e+04    -  6.06e-01 1.00e+00f  1
#   15  0.0000000e+00 9.80e-10 1.82e+03  -1.0 2.36e+04    -  6.47e-01 1.00e+00f  1
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.9653003103268247e-13    3.9653003103268247e-13
#
#
# Number of objective function evaluations             = 77
# Number of objective gradient evaluations             = 17
# Number of equality constraint evaluations            = 77
# Number of inequality constraint evaluations          = 0
# ...
#   57r 7.6539609e+05 7.44e-01 6.33e+01  -4.7 1.29e-01    -  1.00e+00 8.00e-01f  1
#   58r 6.7551800e+05 1.32e+02 2.06e+02  -4.7 5.52e+02    -  1.00e+00 7.44e-01f  1
#   59r 6.8115123e+05 1.17e+02 2.49e+02  -4.7 6.66e+02    -  1.00e+00 1.30e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 6.8114501e+05 1.17e+02 3.66e+02  -4.7 5.91e+02    -  6.79e-01 5.10e-06h  1
#   61r 4.1157727e+03 8.12e+01 2.39e+02  -4.7 5.91e+02    -  8.04e-01 4.60e-01f  1
#   62r 4.1153928e+03 8.12e+01 3.65e+02  -4.7 2.99e+02    -  5.70e-01 2.24e-05h  1
#   63r 2.5418640e+01 3.21e-02 2.11e+00  -4.7 8.12e+01    -  1.00e+00 1.00e+00h  1
#   64r 1.2039435e+01 1.91e-06 4.59e-03  -4.7 1.45e-03    -  1.00e+00 1.00e+00h  1
#   65r 1.2039381e+01 6.02e-08 2.99e-08  -4.7 9.28e-07    -  1.00e+00 1.00e+00h  1
#   66r 1.2039346e+01 1.18e-08 3.57e+01  -7.1 9.70e-05    -  1.00e+00 8.07e-01f  1
#   67r 1.2039350e+01 3.91e-09 4.58e+02  -7.1 7.80e-05    -  9.54e-01 2.83e-01f  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2039349799068138e-07    1.2039349799068138e+01
# Dual infeasibility......:   1.0625181290357943e-17    1.0625181290357943e-09
# Constraint violation....:   3.9135370723516874e-09    3.9135370723516874e-09
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.9135370723516874e-09    3.9135370723516874e-09
#
#
# Number of objective function evaluations             = 70
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 70
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 69
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 67
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.291
# Total CPU secs in NLP function evaluations           =      0.024
#
# EXIT: Optimal Solution Found.
# [K_AUG] 0.1.0, Part of the IDAES PSE framework
# Please visit https://idaes.org/
# : dsdp_mode=
# dsdp_mode=
# W[K_AUG]...	[K_AUG_ASL]No n_rhs declared.
# W[K_AUG]...	[K_AUG_ASL]Target log10mu:= -11.
# W[K_AUG]...	[K_AUG_ASL]This problem has no degrees of freedom
# Pass the option square_override for the desired behaviour
# W[K_AUG_ASL]...	[K_AUG_ASL]No ipopt_zL_in suffix declared, setting zL = 0.
# W[K_AUG_ASL]...	[K_AUG_ASL]No ipopt_zU_in suffix declared, setting zU = 0.
# W[K_AUG]...	[K_AUG_ASL]No f_timestamp suffix declared, Fallback to default writing mode.
# I[K_AUG]...	[K_AUG_ASL] Filename for dot_sens dsdp_in_.in
# W[K_AUG]...	[K_AUG_ASL]dsdp for linear C(x) + I*p = 0 override.
# W[K_AUG]...	[MA57_DRIVER]
#
# 		Could not fix the accuracy of the problem.
# 		Try re-writing the problem or give a different point or change "max_refinement_steps"
# 		Warning: results might be incorrect.
# 		Current residual ratio 1.01325e-10; Max residual ratio 1e-10.
#
# I[K_AUG]...	[K_AUG_ASL]File read successfully.
# I[K_AUG]...	[K_AUG_ASL]Number of Right hand sides: 0
# I[K_AUG]...	[K_AUG_ASL]Number of variables       : 866
# I[K_AUG]...	[K_AUG_ASL]Number of constraints     : 866
# I[K_AUG]...	[K_AUG_ASL]Number of valid n_dof     : 0
# I[K_AUG]...	[ADJUST_MU]	Warning no relevant info from the problem can predict logmu
# I[K_AUG]...	[FIND_INEQUALITIES]summary: eq: 866, leq: 0, geq: 0
# I[K_AUG]...	[K_AUG_ASL]Nonzeroes in the sparse Jacobian 3610
# I[K_AUG]...	[GET_HESS_ASL]Objective found
# I[K_AUG]...	[GET_HESS_ASL]Nonzeroes in the sparse hessian 570
# I[K_AUG]...	[GET_HESS_ASL]Minimization problem detected
# I[K_AUG]...	[GET_HESS_ASL]Current objective 12.039350
# I[K_AUG]...	[GET_HESS_ASL]Missing nz in the Hessian of the Lag: 845
# I[K_AUG]...	[K_AUG_ASL]Barrier term added.
# I[K_AUG]...	[K_AUG_ASL]MC19 scaling...
# I[K_AUG]...	[ASSM_RHS_DCDP]According to the suffixes declared len p is 6
# I[MA57]...	[]***
# I[MA57]...	[ma57bd_]ma57ad_: Status Ok.
# I[MA57]...	[MA57_FACTOR]
# I[K_AUG]...	[MA57_FACTOR]n_neig = 866
# I[K_AUG]...	[INERTIA_STRATEGY]Inertia check successful.
# I[MA57]...	[Factorize Success.]***
# I[MA57]...	[MA57_RATIO]
# I[K_AUG]...	[MA57_SOLVE]: Ratio of norm of scaled residuals (reported); 1.013252e-10
# I[K_AUG]...	[MA57_SOLVE]: The norm of residuals is larger than max ratio(computed)
# I[K_AUG]...	[MA57_SOLVE]: Attempting to reduce residuals
#
# W[K_AUG]...	[MA57_SOLVE]Attempting to make dc > 0. (Jacobian regularization)
# I[K_AUG]...	[INERTIA_STRATEGY]Inertia check successful.
# I[MA57]...	[MA57_FACTOR]
# W[MA57]...	[MA57_FACTOR]always_pert_jacobian is on before fact
# I[K_AUG]...	[MA57_FACTOR]n_neig = 866
# I[K_AUG]...	[INERTIA_STRATEGY]Inertia check successful.
# I[MA57]...	[MA57_RATIO]
# I[K_AUG]...	[MA57_SOLVE]Accuracy improvement tries 0, Trial pivtol 1e-06, Residual ratio 1.0132515814676491e-10.
# I[K_AUG]...	[MA57_SOLVE]Accuracy is not improving.
#
# W[K_AUG]...	[MA57_DRIVER]Inertia check OK neig=866, (neig == m).
# I[K_AUG]...	[K_AUG_ASL]Linear solver done.
# I[K_AUG]...	[K_AUG_ASL]Timings..Ev&Assem 0.038, Fact 0.069, Overall 0.087.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3604
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      866
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.37e+00 1.26e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.35e+00 1.25e+00  -1.0 1.88e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 1.35e+00 2.50e+01  -1.0 1.58e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.13e+00 1.73e+02  -1.0 3.51e+00    -  3.97e-03 5.62e-01f  1
#    4  0.0000000e+00 8.74e-01 5.62e+01  -1.0 1.10e+00    -  8.67e-02 8.88e-01f  1
-1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.7625163e+09 1.14e+00 9.72e+02  -1.0 4.11e+00    -  2.71e-01 4.48e-01f  1
#    2  3.6713750e+08 2.44e+00 2.61e+02  -1.0 6.71e+00    -  3.82e-01 7.19e-01f  1
#    3  8.6144382e+07 6.35e-01 5.84e+01  -1.0 5.91e+00    -  4.98e-01 9.72e-01f  1
#    4  6.2475863e+04 7.36e-03 8.40e+01  -1.0 7.66e-01    -  1.00e+00 9.89e-01h  1
#    5  1.9931236e+01 7.26e-05 7.76e+03  -1.0 8.78e-03    -  1.00e+00 9.90e-01h  1
#    6  1.2436005e+01 1.57e-10 5.85e+00  -1.0 8.65e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2436004523626096e-07    1.2436004523626096e+01
# Dual infeasibility......:   3.9204750557075840e-16    3.9204750557075840e-08
# Constraint violation....:   1.5689196816714990e-10    1.5689196816714990e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.5689196816714990e-10    3.9204750557075840e-08
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.045
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# [K_AUG] 0.1.0, Part of the IDAES PSE framework
# Please visit https://idaes.org/
# : dsdp_mode=
# dsdp_mode=
# W[K_AUG]...	[K_AUG_ASL]No n_rhs declared.
# W[K_AUG]...	[K_AUG_ASL]Target log10mu:= -11.
# W[K_AUG]...	[K_AUG_ASL]This problem has no degrees of freedom
# Pass the option square_override for the desired behaviour
# W[K_AUG_ASL]...	[K_AUG_ASL]No ipopt_zL_in suffix declared, setting zL = 0.
# W[K_AUG_ASL]...	[K_AUG_ASL]No ipopt_zU_in suffix declared, setting zU = 0.
# W[K_AUG]...	[K_AUG_ASL]No f_timestamp suffix declared, Fallback to default writing mode.
# I[K_AUG]...	[K_AUG_ASL] Filename for dot_sens dsdp_in_.in
# W[K_AUG]...	[K_AUG_ASL]dsdp for linear C(x) + I*p = 0 override.
# I[K_AUG]...	[K_AUG_ASL]File read successfully.
# I[K_AUG]...	[K_AUG_ASL]Number of Right hand sides: 0
# I[K_AUG]...	[K_AUG_ASL]Number of variables       : 866
# I[K_AUG]...	[K_AUG_ASL]Number of constraints     : 866
# I[K_AUG]...	[K_AUG_ASL]Number of valid n_dof     : 0
# I[K_AUG]...	[ADJUST_MU]	Warning no relevant info from the problem can predict logmu
# I[K_AUG]...	[FIND_INEQUALITIES]summary: eq: 866, leq: 0, geq: 0
# I[K_AUG]...	[K_AUG_ASL]Nonzeroes in the sparse Jacobian 3610
# I[K_AUG]...	[GET_HESS_ASL]Objective found
# I[K_AUG]...	[GET_HESS_ASL]Nonzeroes in the sparse hessian 570
# I[K_AUG]...	[GET_HESS_ASL]Minimization problem detected
# I[K_AUG]...	[GET_HESS_ASL]Current objective 12.436005
# I[K_AUG]...	[GET_HESS_ASL]Missing nz in the Hessian of the Lag: 845
# I[K_AUG]...	[K_AUG_ASL]Barrier term added.
# I[K_AUG]...	[K_AUG_ASL]MC19 scaling...
# I[K_AUG]...	[ASSM_RHS_DCDP]According to the suffixes declared len p is 6
# I[MA57]...	[]***
# I[MA57]...	[ma57bd_]ma57ad_: Status Ok.
# I[MA57]...	[MA57_FACTOR]
# I[K_AUG]...	[MA57_FACTOR]n_neig = 866
# I[K_AUG]...	[INERTIA_STRATEGY]Inertia check successful.
# I[MA57]...	[Factorize Success.]***
# I[MA57]...	[MA57_RATIO]
# I[K_AUG]...	[MA57_SOLVE]: Ratio of norm of scaled residuals (reported); 7.648324e-12
# I[K_AUG]...	[MA57_SOLVE]Accuracy at an acceptable level.
#
# W[K_AUG]...	[MA57_DRIVER]Inertia check OK neig=866, (neig == m).
# I[K_AUG]...	[K_AUG_ASL]Linear solver done.
# I[K_AUG]...	[K_AUG_ASL]Timings..Ev&Assem 0.035, Fact 0.045, Overall 0.057.

# %%
# get the covariance matrix of the original parameters
cov_comb_orig = get_original_covariance(theta_comb, cov_comb)
print(cov_comb_orig)
# Out:
#               a1            a2            a3            E1            E2  \
# a1  5.480509e+14 -5.108159e+16  1.338953e+21  5.317647e+05 -1.155756e+05
# a2 -5.108159e+16  5.437222e+20  1.901393e+24 -4.957203e+07  1.229970e+09
# a3  1.338953e+21  1.901393e+24  1.098235e+28  1.299328e+12  4.300803e+12
# E1  5.317647e+05 -4.957203e+07  1.299328e+12  5.159669e-04 -1.121644e-04
# E2 -1.155756e+05  1.229970e+09  4.300803e+12 -1.121644e-04  2.782363e-03
# E3  8.152202e+05  1.157381e+09  6.687313e+12  7.911183e-04  2.617875e-03
#
#               E3
# a1  8.152202e+05
# a2  1.157381e+09
# a3  6.687313e+12
# E1  7.911183e-04
# E2  2.617875e-03
# E3  4.072202e-03

# %% [markdown]
# ## Modeling the batch reactor using a variable temperature profile

# %%
def batch_reactor_model_var(XA0, temp_control_points, meas_sample_time):
    """
    Creates a variable temperature Pyomo model for the batch reactor

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    temp_control_points: dict,
        Piecewise-linear profile of the reaction temperature (in R)
    meas_sample_time: list, 
        Timepoints (in hr) to collect samples for mass fraction measurements

    Returns
    -------
    measured_variables: list containing the mass fraction of all species at the sample timepoints
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
    model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
    model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
    model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
    model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
    model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=1-XA0-4e-6)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == pyo.log(m.a1) - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == pyo.log(m.a2) - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == pyo.log(m.a3) - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        return m.dXA[t] == - m.r[1, t] 
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        return m.dXE[t] == 2 * m.r[2, t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        return m.dXG[t] == 1.5 * m.r[3, t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA[t0].fix(XA0)
    model.XB[t0].fix(1 - XA0)
    model.XC[t0].fix(0.0)
    model.XE[t0].fix(0.0)
    model.XG[t0].fix(0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-linear temperature profile
    for t in model.t:
        # if t < 0.5:
        #     temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        # elif t < 1.0:
        #     temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        # elif t < 1.5:
        #     temp_at_time_t = temp_control_points["1.0"] + 0.4 * (t - 1.0)
    
        # elif t < 2.0:
        #     temp_at_time_t = temp_control_points["1.5"] + 0.4 * (t - 1.5)
    
        # else:
        #     temp_at_time_t = temp_control_points["2.0"] + 0.2 * (t - 2.0)
        
        if t < 0.5:
            temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        elif t < 1.0:
            temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        else:
            temp_at_time_t = 6.2
    
        model.T_reparam[t].fix(1 / temp_at_time_t)

    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    # model.pprint()

    # get the mass fraction of all species
    time = [t for t in model.t]
    print("The timepoints are:",time)
    XA_values = [pyo.value(model.XA[t]) for t in model.t]
    XB_values = [pyo.value(model.XB[t]) for t in model.t] 
    XC_values = [pyo.value(model.XC[t]) for t in model.t] 
    XP_values = [pyo.value(model.XP[t]) for t in model.t] 
    XE_values = [pyo.value(model.XE[t]) for t in model.t] 
    XG_values = [pyo.value(model.XG[t]) for t in model.t]

     # Plot the results
    temp_values = [1 / pyo.value(model.T_reparam[t]) for t in model.t]
    plt.figure(figsize=(8, 6))
    plt.plot(time, temp_values,)
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Temperature (R)', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(time, XA_values, label='A')
    plt.plot(time, XB_values, label='B')
    plt.plot(time, XC_values, label='C')
    plt.plot(time, XP_values, label='P')
    plt.plot(time, XE_values, label='E')
    plt.plot(time, XG_values, label='G')
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
    plt.savefig("batch_reactor_var_temp.png")
    plt.show()

    # store the mass fraction of all species at the sample time
    measured_variables = []
    for sample_time in meas_sample_time:
        measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
                                   pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

    print("Mass fraction of species at the sample time:",measured_variables)
    return measured_variables

# %%
# define the temperature control points and sample time for mass fraction measurements
temp_control = {"0.0":5.8, "0.5":5.9, "1.0":6.2, "1.5":6.4, "2.0":6.6, "3.0":6.8}
meas_sample_time_var = [0.5, 1.5, 3]

# get the ground-truth simulation of the mass fractions
measured_var = batch_reactor_model_var(0.4, temp_control, meas_sample_time_var)

# make a dataframe of the measured variables
measured_var_df = ground_truth_data(measured_var)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3322
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      723
#
# Total number of variables............................:     1215
#                      variables with only lower bounds:      549
#                 variables with lower and upper bounds:      361
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1215
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.54e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00
 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55, 1.6, 1.65, 1.7, 1.75, 1.8, 1.85, 1.9, 1.95, 2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85, 2.9, 2.95, 3]
# Mass fraction of species at the sample time: [[0.1474655995917531, 0.14906125079769383, 0.04914998638390844, 0.16884929009064828, 0.3968086974452402, 0.08866517567908094], [0.06241996817778143, 0.01643428694145589, 0.0030939251056064597, 0.15593829257263647, 0.491971361915891, 0.2701421652854945], [0.04956254474055381, 0.0022965814233672976, 0.0004189153523346468, 0.14430392828785563, 0.49453192506360805, 0.3088861051309002]]
#
# Output variables:
#           XA        XB        XC        XP        XE        XG
# 0  0.147466  0.149061  0.049150  0.168849  0.396809  0.088665
# 1  0.062420  0.016434  0.003094  0.155938  0.491971  0.270142
# 2  0.049563  0.002297  0.000419  0.144304  0.494532  0.308886

# %% [markdown]
# ### Add Gaussian noise to the ground-truth simulations

# %%
# generate noisy mass fraction measurements
A_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XA"], mass_frac_std)
B_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XP"], mass_frac_std)
E_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XE"], mass_frac_std)
G_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XG"], mass_frac_std)

# define a matrix that contains the sample time and mass fractions
data_matrix_var = np.zeros((n_samples, 7))
data_matrix_var[:, 0] = meas_sample_time_var
data_matrix_var[:, 1] = A_noisy_mass_fraction_var
data_matrix_var[:, 2] = B_noisy_mass_fraction_var
data_matrix_var[:, 3] = C_noisy_mass_fraction_var
data_matrix_var[:, 4] = P_noisy_mass_fraction_var
data_matrix_var[:, 5] = E_noisy_mass_fraction_var
data_matrix_var[:, 6] = G_noisy_mass_fraction_var

# %% [markdown]
# ### Compile the generated data into a csv file

# %%
data_var = synthetic_data_compiler(data_matrix_var, "batch_reactor_var_temp")
# Out:
# Generated data:
#     Time (hr)        XA        XB        XC        XP        XE        XG
# 0        0.5  0.160781  0.149063  0.049151  0.182165  0.410125  0.101981
# 1        1.5  0.069573  0.016435  0.003095  0.163091  0.499124  0.277295
# 2        3.0  0.034109  0.002295  0.000417  0.128850  0.479078  0.293432

# %% [markdown]
# ### Reformulate the batch reactor model for parameter estimation

# %%
def reform_batch_reactor_model_var(XA0, temp_control_points):
    """
    Reformulates the variable temperature batch reactor model for parameter estimation

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    temp_control_points: dict,
        Piecewise-linear profile of the reaction temperature (in R)

    Returns
    -------
    model: Pyomo model of the variable temperature batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=1-XA0-4e-6)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=1e-6)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == model.alpha_1 - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == model.alpha_2 - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == model.alpha_3 - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        return m.dXA[t] == - m.k[1, t] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        return m.dXB[t] == - (m.k[1, t] * m.XA[t] * m.XB[t] + m.k[2, t] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        return m.dXC[t] == 2 * m.k[1, t] * m.XA[t] * m.XB[t] - 2 * m.k[2, t] * m.XB[t] * m.XC[t] - m.k[3, t] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        return m.dXE[t] == 2 * m.k[2, t] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        return m.dXG[t] == 1.5 * m.k[3, t] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == 1 - XA0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-linear temperature profile
    for t in model.t:
        # if t < 0.5:
        #     temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        # elif t < 1.0:
        #     temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        # elif t < 1.5:
        #     temp_at_time_t = temp_control_points["1.0"] + 0.4 * (t - 1.0)
    
        # elif t < 2.0:
        #     temp_at_time_t = temp_control_points["1.5"] + 0.4 * (t - 1.5)
    
        # else:
        #     temp_at_time_t = temp_control_points["2.0"] + 0.2 * (t - 2.0)

        if t < 0.5:
            temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        elif t < 1.0:
            temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        else:
            temp_at_time_t = 6.2
    
        model.T_reparam[t].fix(1 / temp_at_time_t)
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %% [markdown]
# ### Estimate the unknown model parameters

# %%
objective_val, estimated_params, cov_matrix_est = parameter_covariance_est(data_var, XA0=0.4, 
                                                                           temp_control=temp_control, 
                                                                           const_temp=False)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     4504
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      732
#
# Total number of variables............................:     1226
#                      variables with only lower bounds:      555
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1220
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.93e+00 1.16e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.89e+00 1.14e+00  -1.0 4.42e+01    -  1.75e-02 1.66e-02h  1
#    2  0.0000000e+00 8.57e-01 5.35e+01  -1.0 4.95e+01    -  2.00e-02 5.47e-01f  1
#    3  0.0000000e+00 4.19e-01 2.52e+01  -1.0 1.87e+01    -  8.80e-02 5.11e-01f  1
#    4  0.0000000e+00 5.08e-02 1.53e+01  -1.0 6.80e+00    -  6.66e-01 9.89e-01f  1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   5.1242400175345189e-14    5.1242400175345189e-14
# Constraint violation....:   1.0186340659856796e-10    1.0186340659856796e-10
# Complementarity.........:   2.5059035596800626e-09    2.5059035596800626e-09
# Overall NLP error.......:   2.5059035596800626e-09    2.5059035596800626e-09
#
#
# Number of objective function evaluations             = 58
# Number of objective gradient evaluations             = 40
# Number of equality constraint evaluations            = 58
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 40
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 39
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.259
# Total CPU secs in NLP function evaluations           =      0.052
#
# EXIT: Optimal Solution Found.
# Covariance matrix of reformulated parameters:
#            alpha_1   alpha_2   alpha_3        E1        E2        E3
# alpha_1  0.006107 -0.013887  0.006905  0.035608 -0.081505  0.039276
# alpha_2 -0.013887  0.033447 -0.018210 -0.081067  0.196482 -0.104913
# alpha_3  0.006905 -0.018210  0.011348  0.040397 -0.107119  0.066409
# E1       0.035608 -0.081067  0.040397  0.207616 -0.475802  0.229844
# E2      -0.081505  0.196482 -0.107119 -0.475802  1.154235 -0.617267
# E3       0.039276 -0.104913  0.066409  0.229844 -0.617267  0.389320
#
# The prior FIM for Pyomo.DoE is:
#  [[ 1.54923892e+10  1.46768762e+09 -1.70117015e+09 -2.64078844e+09
#   -2.47886697e+08  2.88800452e+08]
#  [ 1.46768748e+09  2.62585093e+09  2.82305000e+08 -2.50870082e+08
#   -4.46282047e+08 -4.80860291e+07]
#  [-1.70117017e+09  2.82304983e+08  3.17901387e+08  2.88574384e+08
#   -4.84467545e+07 -5.37122208e+07]
#  [-2.64078844e+09 -2.50870105e+08  2.88574380e+08  4.50173686e+08
#    4.23788912e+07 -4.89966838e+07]
#  [-2.47886674e+08 -4.46282047e+08 -4.84467574e+07  4.23788872e+07
#    7.58506994e+07  8.25059622e+06]
#  [ 2.88800456e+08 -4.80860262e+07 -5.37122208e+07 -4.89966845e+07
#    8.25059573e+06  9.07667054e+06]]

# %%
print("Estimates of the original parameters:\n",estimated_params)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_est)
# Out:
# Estimates of the original parameters:
#  {'a1': 6534678859.634441, 'a2': 1943866661314.7957, 'a3': 1.1955253301177572e+16, 'E1': 120.52618567948294, 'E2': 148.29363289630214, 'E3': 201.29320263575312}
#
# Covariance matrix of the original parameters:
#                a1            a2            a3            E1            E2  \
# a1  2.607879e+17 -1.764016e+20  5.394537e+23  2.326852e+08 -5.326094e+08
# a2 -1.764016e+20  1.263834e+23 -4.231820e+26 -1.575836e+11  3.819347e+11
# a3  5.394537e+23 -4.231820e+26  1.621896e+30  4.829513e+14 -1.280639e+15
# E1  2.326852e+08 -1.575836e+11  4.829513e+14  2.076162e-01 -4.758019e-01
# E2 -5.326094e+08  3.819347e+11 -1.280639e+15 -4.758019e-01  1.154235e+00
# E3  2.566532e+08 -2.039363e+11  7.939356e+14  2.298436e-01 -6.172666e-01
#
#               E3
# a1  2.566532e+08
# a2 -2.039363e+11
# a3  7.939356e+14
# E1  2.298436e-01
# E2 -6.172666e-01
# E3  3.893196e-01
