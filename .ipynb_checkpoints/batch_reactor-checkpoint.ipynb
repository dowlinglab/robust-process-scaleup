# %%
import pyomo.environ as pyo
import math
import pandas as pd
import numpy as np
from scipy import stats
import pyomo.dae as dae
import matplotlib.pyplot as plt
from pyomo.contrib.parmest.experiment import Experiment
from pyomo.contrib.doe import DesignOfExperiments
from pyomo.contrib.parmest import parmest

# %% [markdown]
# # Modeling a lab-scale batch reactor to scale-up the Williams-Otto process

# %% [markdown]
# ## Create the functions to be used in this notebook

# %%
class BatchReactorExperiment(Experiment):
    """Creates and labels the Pyomo model of the batch reactor
    
    Parameters
    ----------
    data: Pandas dataframe or .csv file,
        Data containing the sample time and measured values of mass fractions 
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp_control: int, float, or dict,
        Constant or piecewise-linear profile of the reaction temperature (in R)
    const_temp: Boolean,
        Choose between a constant or variable temperature profile

    Returns
    -------
    m: annotated Pyomo model of the batch reactor
    """

    def __init__(self, data, XA0, XB0, temp_control, const_temp, low_high_temp):

        self.data = data
        self.XA0 = XA0
        self.XB0 = XB0
        self.temp_control = temp_control
        self.const_temp = const_temp
        self.low_high_temp = low_high_temp
        self.model = None

    def get_labeled_model(self):
        self.create_model()
        self.label_model()

        return self.model

    def create_model(self):
        if self.const_temp and not self.low_high_temp:
            self.model = reform_batch_reactor_model_const(self.XA0, self.XB0, self.temp_control)
        elif self.low_high_temp and not self.const_temp:
            self.model = reform_batch_reactor_model_comb(self.XA0, self.XB0)
        elif not self.const_temp and not self.low_high_temp:
            self.model = reform_batch_reactor_model_var(self.XA0, self.XB0, self.temp_control)

        return self.model

    def label_model(self):

        m = self.model

        meas_time_points = self.data["Time (hr)"]

        # label the measured variables
        m.experiment_outputs = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.experiment_outputs.update(
            (m.XA[t], self.data["XA"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XB[t], self.data["XB"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XC[t], self.data["XC"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XP[t], self.data["XP"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XE[t], self.data["XE"][ind]) for ind, t in enumerate(meas_time_points)
        )
        m.experiment_outputs.update(
            (m.XG[t], self.data["XG"][ind]) for ind, t in enumerate(meas_time_points)
        )

        # label the unknown parameters
        m.unknown_parameters = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.unknown_parameters.update(
            (k, pyo.ComponentUID(k)) for k in [m.alpha_1, m.alpha_2, m.alpha_3, m.E1, m.E2, m.E3]
        )

        # add the measurement errors
        m.measurement_error = pyo.Suffix(direction=pyo.Suffix.LOCAL)
        m.measurement_error.update(
            (m.XA[t], 0.01) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XB[t], 1e-06) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XC[t], 1e-06) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XP[t], 0.01) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XE[t], 0.01) for t in meas_time_points
        )
        m.measurement_error.update(
            (m.XG[t], 0.01) for t in meas_time_points
        )

        return m

# %%
def parameter_covariance_est(data, XA0, XB0, temp_control=None, const_temp=True, low_high_temp=False):
    """Estimates the parameters and covariance matrix of the batch reactor model from the data

    Parameters
    ----------
    data: Pandas dataframe or .csv file,
        Data containing the sample time and measured values of mass fractions 
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp_control: int, float, or dict,
        Constant or piecewise-linear profile of the reaction temperature (in R)
    const_temp: Boolean,
        Choose between a constant or variable temperature profile

    Returns
    -------
    theta_original: dictionary containing estimates of the parameters
    cov_theta_df: Pandas dataframe containing the covariance matrix of the estimated parameters
    """

    # create a list of the experiment class
    exp_list = [BatchReactorExperiment(data, XA0, XB0, temp_control, const_temp, low_high_temp)]
    
    # Create the Estimator object
    pest = parmest.Estimator(exp_list, obj_function="SSE_weighted", tee=True)  
    
    # Estimate the reformulated parameters
    obj, theta = pest.theta_est()

    # get the original a1, a2, and a3 parameters
    a1 = np.exp(theta['alpha_1'])
    a2 = np.exp(theta['alpha_2'])
    a3 = np.exp(theta['alpha_3'])

    # create a new dictionary for the original parameters
    theta_original = {"a1":a1, "a2":a2, "a3":a3, "E1": theta["E1"], "E2": theta["E2"], "E3": theta["E3"]}

    try:
        # compute the covariance matrix of the reformulated parameters
        cov_beta = pest.cov_est(method="finite_difference")
        
        # derivative of a1 w.r.t. all the parameters given that a1 = exp(alpha_1)
        da1_dalpha_1 = np.exp(theta['alpha_1'])
        da1_dalpha_2 = 0
        da1_dalpha_3 = 0
        da1_dE1 = 0
        da1_dE2 = 0
        da1_dE3 = 0
        da1_dbeta = [da1_dalpha_1, da1_dalpha_2, da1_dalpha_3, da1_dE1, da1_dE2, da1_dE3]
        
        # derivative of a2 w.r.t. all the parameters given that a2 = exp(alpha_2)
        da2_dalpha_1 = 0
        da2_dalpha_2 = np.exp(theta['alpha_2'])
        da2_dalpha_3 = 0
        da2_dE1 = 0
        da2_dE2 = 0
        da2_dE3 = 0
        da2_dbeta = [da2_dalpha_1, da2_dalpha_2, da2_dalpha_3, da2_dE1, da2_dE2, da2_dE3]
        
        # derivative of a3 w.r.t. all the parameters given that a3 = exp(alpha_3)
        da3_dalpha_1 = 0
        da3_dalpha_2 = 0
        da3_dalpha_3 = np.exp(theta['alpha_3'])
        da3_dE1 = 0
        da3_dE2 = 0
        da3_dE3 = 0
        da3_dbeta = [da3_dalpha_1, da3_dalpha_2, da3_dalpha_3, da3_dE1, da3_dE2, da3_dE3]
    
        # derivative of E1 w.r.t. all the parameters given that E1 = E1
        dE1_dalpha_1 = 0
        dE1_dalpha_2 = 0
        dE1_dalpha_3 = 0
        dE1_dE1 = 1
        dE1_dE2 = 0
        dE1_dE3 = 0
        dE1_dbeta = [dE1_dalpha_1, dE1_dalpha_2, dE1_dalpha_3, dE1_dE1, dE1_dE2, dE1_dE3]
        
        # derivative of E2 w.r.t. all the parameters given that E2 = E2
        dE2_dalpha_1 = 0
        dE2_dalpha_2 = 0
        dE2_dalpha_3 = 0
        dE2_dE1 = 0
        dE2_dE2 = 1
        dE2_dE3 = 0
        dE2_dbeta = [dE2_dalpha_1, dE2_dalpha_2, dE2_dalpha_3, dE2_dE1, dE2_dE2, dE2_dE3]
        
        # derivative of E3 w.r.t. all the parameters given that E3 = E3
        dE3_dalpha_1 = 0
        dE3_dalpha_2 = 0
        dE3_dalpha_3 = 0
        dE3_dE1 = 0
        dE3_dE2 = 0
        dE3_dE3 = 1
        dE3_dbeta = [dE3_dalpha_1, dE3_dalpha_2, dE3_dalpha_3, dE3_dE1, dE3_dE2, dE3_dE3]
        
        # Jacobian matrix
        dtheta_dbeta = np.zeros((6, 6))
        dtheta_dbeta[0, :] = da1_dbeta
        dtheta_dbeta[1, :] = da2_dbeta
        dtheta_dbeta[2, :] = da3_dbeta
        dtheta_dbeta[3, :] = dE1_dbeta
        dtheta_dbeta[4, :] = dE2_dbeta
        dtheta_dbeta[5, :] = dE3_dbeta
    
        # calculate the covariance matrix of the original parameters
        cov_theta = dtheta_dbeta @ cov_beta @ dtheta_dbeta.T
        cov_theta_df = pd.DataFrame(
                                    cov_theta.to_numpy(),
                                    index=["a1", "a2", "a3", "E1", "E2", "E3"],
                                    columns=["a1", "a2", "a3", "E1", "E2", "E3"],)

        return obj, theta_original, cov_theta_df
    except RuntimeError:
        return obj, theta_original, ["N/A"]

# %%
def ground_truth_data(measured_var):
    """Creates a Pandas dataframe for ground-truth simulation of mass fractions

    Parameters
    ----------
    measured_var: 2D numpy array or matrix,
        matrix containing ground-truth simulation of mass fractions

    Returns
    -------
    outputs: Pandas dataframe containing ground-truth simulation of mass fractions 
    """
    
    # name of experimental outputs
    output_names = ["XA", "XB", "XC", "XP", "XE", "XG"]
    
    # outputs dataframe
    outputs = pd.DataFrame(measured_var, columns=output_names)
    
    print("\nOutput variables:\n",outputs)

    return outputs

def generate_noisy_measurement(mass_frac, mass_frac_std):
    """Generates noisy measurement of mass fractions

    Parameters
    ----------
    mass_frac: Pandas series or list,
        A list or Pandas series containing mass fractions
    mass_frac_std: float,
        Standard deviation of the mass fraction measurement errors

    Returns
    -------
    noisy_mass_frac: A list containing noisy measurement of mass fractions
    """
    
    # generate gaussian noise
    np.random.seed(10)
    noise = stats.norm.rvs(loc=0, scale=mass_frac_std, size=len(mass_frac))
    
    # corrupt the mass fraction with the noise
    noisy_mass_frac = mass_frac + noise
    
    return noisy_mass_frac

def synthetic_data_compiler(data_matrix, csv_name):
    """Generates noisy measurement of mass fractions

    Parameters
    ----------
    data_matrix: 2D numpy array or matrix,
        matrix containing the noisy measurement of mass fractions 
    csv_name: str,
        Csv file name

    Returns
    -------
    data: Pandas dataframe containing the generated data
    """
    # data columns
    column_names = ["Time (hr)", "XA", "XB", "XC", "XP", "XE", "XG"]
    
    # number of data columns
    n_columns = len(column_names)
    
    # full data
    data = pd.DataFrame(data_matrix, columns=column_names)
    print("Generated data:\n",data)
    
    data.to_csv(f"{csv_name}.csv", index=False)

    return data

# %% [markdown]
# ## Modeling the batch reactor using a constant temperature profile

# %%
def batch_reactor_model_const(XA0, XB0, temp, meas_sample_time):
    """
    Creates a constant temperature Pyomo model for the batch reactor

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp: int or float,
        Constant reaction temperature in R
    meas_sample_time: list,
        Timepoints (in hr) to collect samples for mass fraction measurements

    Returns
    -------
    measured_variables: list containing the mass fraction of all species at the sample timepoints
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
    model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
    model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
    model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
    model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
    model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(bounds=(0, 1))
    model.T_reparam.fix(1/temp)

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
    model.k = pyo.Var(reaction_number, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i):
        if i == 1:
            return m.k_reparam[i] == pyo.log(m.a1) - m.E1 * m.T_reparam
        elif i == 2:
            return m.k_reparam[i] == pyo.log(m.a2) - m.E2 * m.T_reparam
        else:
            return m.k_reparam[i] == pyo.log(m.a3) - m.E3 * m.T_reparam
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i):
        return m.k[i] == pyo.exp(m.k_reparam[i])
    
    model.k_eq = pyo.Constraint(
        reaction_number, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.r[1, t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.r[2, t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.r[3, t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA[t0].fix(XA0)
    model.XB[t0].fix(XB0)
    model.XC[t0].fix(0)
    model.XE[t0].fix(0)
    model.XP[t0].fix(0)
    model.XG[t0].fix(0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)

    # get the mass fraction of all species
    time = [t for t in model.t]
    print("The timepoints are:",time)
    XA_values = [pyo.value(model.XA[t]) for t in model.t]
    XB_values = [pyo.value(model.XB[t]) for t in model.t] 
    XC_values = [pyo.value(model.XC[t]) for t in model.t] 
    XP_values = [pyo.value(model.XP[t]) for t in model.t] 
    XE_values = [pyo.value(model.XE[t]) for t in model.t] 
    XG_values = [pyo.value(model.XG[t]) for t in model.t] 
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(time, XA_values, label='$\mathrm{X_{A}}$')
    plt.plot(time, XB_values, label='$\mathrm{X_{B}}$')
    plt.plot(time, XC_values, label='$\mathrm{X_{C}}$')
    plt.plot(time, XP_values, label='$\mathrm{X_{P}}$')
    plt.plot(time, XE_values, label='$\mathrm{X_{E}}$')
    plt.plot(time, XG_values, label='$\mathrm{X_{G}}$')
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
    # plt.savefig("batch_reactor_const_temp.png")
    plt.show()

    # store the mass fraction of all species at the sample time
    measured_variables = []
    for sample_time in meas_sample_time:
        measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
                                   pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

    print("Mass fraction of species at the sample time:",measured_variables)
    return measured_variables

# %%
# define the constant temperature and sample time for mass fraction measurements
high_const_temp = 6.8
sample_time_high_temp = [0.5, 1.5, 3]

# get the ground-truth simulation of the mass fractions
measured_var_high_temp = batch_reactor_model_const(0.4, 0.6, high_const_temp, sample_time_high_temp)

# make a dataframe of the measured variables
outputs_df_high_temp = ground_truth_data(measured_var_high_temp)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2947
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      543
#
# Total number of variables............................:      909
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:      360
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      909
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.58e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.01e+00 1.27e+03  -1.0 4.75e+00    -  2.13e-03 1.58e-01f  1
#    2  0.0000000e+00 2.97e+00 1.25e+03  -1.0 6.39e+00    -  8.79e-03 1.27e-02f  1
#    3  0.0000000e+00 2.97e+00 1.25e+03  -1.0 6.51e+00    -  3.31e-02 1.44e-04h  1
#    4r 0.0000000e+00 2.97e+00 9.99e+02   0.5 0.00e+00    -  0.00e+00 3.60e-07R  3
#    5r 0.0000000e+00 3.26e+00 9.93e+02   0.5 2.85e+02    -  3.55e-03 5.56e-03f  1
#    6r 0.0000000e+00 3.15e+00 9.83e+02   0.5 1.04e+02    -  1.73e-02 1.04e-02f  1
#    7r 0.0000000e+00 2.72e+00 9.68e+02   0.5 7.61e+01    -  2.50e-02 1.52e-02f  1
#    8r 0.0000000e+00 2.30e+00 9.43e+02   0.5 6.02e+01    -  1.71e-02 2.62e-02f  1
#    9r 0.0000000e+00 2.04e+00 9.27e+02   0.5 4.94e+01    -  8.73e-03 4.35e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 1.93e+00 9.08e+02   0.5 3.34e+01    -  2.04e-02 2.26e-02f  1
#   11r 0.0000000e+00 1.81e+00 8.15e+02   0.5 1.86e+01    -  9.89e-02 1.42e-01f  1
#   12r 0.0000000e+00 1.54e+00 7.69e+02   0.5 3.44e+01    -  6.40e-02 4.62e-02f  1
#   13r 0.0000000e+00 1.28e+00 5.83e+02   0.5 1.31e+01    -  3.54e-01 2.43e-01f  1
#   14r 0.0000000e+00 2.10e+00 1.46e+03   0.5 1.29e+01    -  1.00e+00 4.37e-01f  1
#   15r 0.0000000e+00 1.09e+00 1.63e+03   0.5 6.39e+00    -  4.14e-01 5.52e-01f  1
#   16r 0.0000000e+00 4.87e-01 3.36e+03   0.5 3.64e+00    -  5.49e-01 1.00e+00f  1
#   17r 0.0000000e+00 5.04e-01 8.63e+01   0.5 1.00e+00    -  1.00e+00 1.00e+00f  1
#   18r 0.0000000e+00 4.76e-01 1.93e+02  -0.2 1.31e+00    -  1.00e+00 4.60e-01f  1
#   19r 0.0000000e+00 1.35e+00 1.18e+02  -0.2 1.09e+01    -  1.00e+00 6.75e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 6.66e-01 2.41e+02  -0.2 5.33e+00    -  1.00e+00 5.67e-01f  1
#   21r 0.0000000e+00 3.93e-02 2.38e+00  -0.2 2.27e+00    -  1.00e+00 1.00e+00f  1
#   22r 0.0000000e+00 1.57e-02 4.93e+01  -1.6 9.99e-01    -  1.00e+00 8.38e-01f  1
#   23r 0.0000000e+00 1.58e-02 6.01e+02  -1.6 7.89e+00    -  1.00e+00 2.29e-02f  1
#   24r 0.0000000e+00 4.12e-05 1.41e+00  -1.6 1.66e-02    -  1.00e+00 1.00e+00f  1
#   25r 0.0000000e+00 4.12e-05 1.57e-04  -1.6 5.91e-04    -  1.00e+00 1.00e+00f  1
#   26r 0.0000000e+00 2.04e-06 4.91e+00  -3.7 3.58e-04    -  1.00e+00 9.62e-01f  1
#   27r 0.0000000e+00 3.95e-07 1.94e+00  -3.7 2.46e-05    -  1.00e+00 9.89e-01f  1
#   28r 0.0000000e+00 3.78e-07 6.68e-07  -3.7 1.25e-05    -  1.00e+00 1.00e+00f  1
#   29r 0.0000000e+00 2.10e-09 5.22e-01  -8.2 5.25e-07    -  1.00e+00 9.88e-01f  1
#
# Number of Iterations....: 29
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.0951084145191718e-09    2.0951084145191718e-09
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.0951084145191718e-09    2.0951084145191718e-09
#
#
# Number of objective function evaluations             = 33
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 33
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 31
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 29
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.170
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# The timepoints are: [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55, 1.6, 1.65, 1.7, 1.75, 1.8, 1.85, 1.9, 1.95, 2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85, 2.9, 2.95, 3]
# Mass fraction of species at the sample time: [[0.11671429330522841, 0.09776663762071133, 0.027702863719516156, 0.1684610364929613, 0.4378953113468477, 0.15145985751212251], [0.0672282827900561, 0.02319758749719939, 0.006727972760070488, 0.15865365968990727, 0.48806139049086483, 0.2561311067717398], [0.053442158101238875, 0.0066482174956311165, 0.001940336850251773, 0.1480002076984508, 0.4935878809907925, 0.29638119886281744]]
#
# Output variables:
#           XA        XB        XC        XP        XE        XG
# 0  0.116714  0.097767  0.027703  0.168461  0.437895  0.151460
# 1  0.067228  0.023198  0.006728  0.158654  0.488061  0.256131
# 2  0.053442  0.006648  0.001940  0.148000  0.493588  0.296381

# %% [markdown]
# ### Add Gaussian noise to the ground-truth simulations

# %%
# define the standard deviation of the mass fraction measurement errors
mass_frac_std = 0.01
B_C_mass_frac_std = 1e-06

# generate noisy mass fraction measurements
A_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XA"], mass_frac_std)
B_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XP"], mass_frac_std)
E_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XE"], mass_frac_std)
G_noisy_mass_fraction_high = generate_noisy_measurement(outputs_df_high_temp["XG"], mass_frac_std)

# get the number of time samples
n_samples = len(sample_time_high_temp)

# define a matrix that contains the sample time and mass fractions
data_matrix_high = np.zeros((n_samples, 7))
data_matrix_high[:, 0] = sample_time_high_temp
data_matrix_high[:, 1] = A_noisy_mass_fraction_high
data_matrix_high[:, 2] = B_noisy_mass_fraction_high
data_matrix_high[:, 3] = C_noisy_mass_fraction_high
data_matrix_high[:, 4] = P_noisy_mass_fraction_high
data_matrix_high[:, 5] = E_noisy_mass_fraction_high
data_matrix_high[:, 6] = G_noisy_mass_fraction_high

# %% [markdown]
# ### Compile the generated data into a csv file

# %%
data_high_temp = synthetic_data_compiler(data_matrix_high, "batch_reactor_const_temp")
# Out:
# Generated data:
#     Time (hr)        XA        XB        XC        XP        XE        XG
# 0        0.5  0.130030  0.097768  0.027704  0.181777  0.451211  0.164776
# 1        1.5  0.074381  0.023198  0.006729  0.165806  0.495214  0.263284
# 2        3.0  0.037988  0.006647  0.001939  0.132546  0.478134  0.280927

# %% [markdown]
# ### Reformulate the batch reactor model for parameter estimation

# %%
def reform_batch_reactor_model_const(XA0, XB0, temp):
    """
    Reformulates the constant temperature batch reactor model for parameter estimation

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp: int or float,
        Constant reaction temperature in R

    Returns
    -------
    model: Pyomo model of the batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(bounds=(0, 1))
    model.T_reparam.fix(1/temp)

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, bounds=(0, None))
    model.k = pyo.Var(reaction_number, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i):
        if i == 1:
            return m.k_reparam[i] == model.alpha_1 - m.E1 * m.T_reparam
        elif i == 2:
            return m.k_reparam[i] == model.alpha_2 - m.E2 * m.T_reparam
        else:
            return m.k_reparam[i] == model.alpha_3 - m.E3 * m.T_reparam
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i):
        return m.k[i] == pyo.exp(m.k_reparam[i])
    
    model.k_eq = pyo.Constraint(
        reaction_number, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.k[1] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.k[1] * m.XA[t] * m.XB[t] + m.k[2] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.k[1] * m.XA[t] * m.XB[t] - 2 * m.k[2] * m.XB[t] * m.XC[t] - m.k[3] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.k[2] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.k[3] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == XB0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XP_init = pyo.Constraint(expr=model.XP[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %%
obj_high, estimated_params_high, cov_matrix_high = parameter_covariance_est(data_high_temp, XA0=0.4, XB0=0.6, 
                                                            temp_control=high_const_temp, const_temp=True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3753
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      921
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      915
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.66e+00 1.26e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.64e+00 1.24e+00  -1.0 2.15e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 1.63e+00 2.50e+01  -1.0 1.58e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.10e+00 1.73e+02  -1.0 3.50e+00    -  3.99e-03 5.62e-01f  1
#    4  0.0000000e+00 8.63e-01 5.67e+01  -1.0 1.21e+00    -  8.67e-02 8.88e-01f  1
#    5  0.0000000e+00 4.33e-01 8.22e+01  -1.0 5.96e-01   2.0 4.98e-01 6.26e-01h  1
#    6  0.0000000e+00 2.86e-02 5.04e+03  -1.0 2.05e-01   1.5 9.94e-01 9.90e-01h  1
#    7  0.0000000e+00 1.79e-02 2.89e+04  -1.0 2.35e-01   1.0 4.63e-01 9.95e-01f  1
#    8  0.0000000e+00 4.58e-01 2.94e+06  -1.0 3.52e+01    -  4.56e-01 1.00e+00f  1
#    9  0.0000000e+00 4.34e-03 5.58e+05  -1.0 4.32e-01   0.6 9.33e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 4.07e-01 4.62e+05  -1.0 8.65e+01    -  7.49e-01 1.00e+00f  1
#   11  0.0000000e+00 8.07e-01 4.61e+04  -1.0 3.48e+02    -  9.00e-01 1.00e+00f  1
#   12  0.0000000e+00 1.18e-02 3.48e+04  -1.0 3.40e+03    -  2.45e-01 1.00e+00f  1
#   13  0.0000000e+00 9.54e-04 1.25e+04  -1.0 4.44e+03    -  6.41e-01 1.00e+00f  1
#   14  0.0000000e+00 1.23e-05 4.91e+03  -1.0 1.15e+04    -  6.07e-01 1.00e+00f  1
#   15  0.0000000e+00 2.22e-09 1.71e+03  -1.0 2.45e+04    -  6.51e-01 1.00e+00f  1
#   16  0.0000000e+00 4.30e-10 4.26e+02  -1.0 4.52e+04    -  7.52e-01 1.00e+00f  1
#   17  0.0000000e+00 1.94e-12 1.36e+04  -1.7 1.16e+04    -  9.98e-01 1.00e+00f  1
#   18  0.0000000e+00 6.97e-12 2.00e-07  -1.7 7.40e+04    -  1.00e+00 1.00e+00f  1
#   19  0.0000000e+00 3.64e-12 5.65e-05  -5.7 7.50e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20
#  284r 0.0000000e+00 2.09e+02 5.72e+03  -9.0 6.33e+03    -  6.09e-01 5.05e-01f  1
#  285r 0.0000000e+00 1.98e+02 5.40e+03  -9.0 3.70e+03    -  2.99e-01 5.51e-02f  1
#  286r 0.0000000e+00 1.61e+02 4.05e+03  -9.0 3.51e+03    -  1.00e+00 2.35e-01f  1
#  287r 0.0000000e+00 1.30e+02 2.90e+03  -9.0 2.75e+03    -  2.13e-01 2.28e-01f  1
#  288r 0.0000000e+00 6.85e+01 9.81e+02  -9.0 2.16e+03    -  4.29e-01 7.24e-01f  1
#  289r 0.0000000e+00 2.06e+01 2.65e+02  -9.0 6.46e+02    -  9.42e-01 9.99e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290r 0.0000000e+00 2.06e+01 5.35e-02  -9.0 4.53e+00    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 290
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   2.2597011099330516e-02    2.2597011099330516e-02
# Constraint violation....:   2.0601001136436260e+01    2.0601001136436260e+01
# Complementarity.........:   9.0959571671455824e-10    9.0959571671455824e-10
# Overall NLP error.......:   2.0601001136436260e+01    2.0601001136436260e+01
#
#
# Number of objective function evaluations             = 609
# Number of objective gradient evaluations             = 84
# Number of equality constraint evaluations            = 612
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 296
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 291
# Total CPU secs in IPOPT (w/o function evaluations)   =      2.164
# Total CPU secs in NLP function evaluations           =      0.116
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %%
print("Estimates of the original parameters:\n",estimated_params_high)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_high)
# Out:
# Estimates of the original parameters:
#  {'a1': inf, 'a2': inf, 'a3': inf, 'E1': 171421.03906123113, 'E2': 171417.81692754713, 'E3': 171418.16201319557}
#
# Covariance matrix of the original parameters:
#  ['N/A']

# %% [markdown]
# ### Low temperature constant batch reactor

# %%
# define the constant temperature and sample time for mass fraction measurements
low_const_temp = 5.8
sample_time_low_temp = [0.75, 1, 2.5]

# get the ground-truth simulation of the mass fractions
measured_var_low_temp = batch_reactor_model_const(0.4, 0.6, low_const_temp, sample_time_low_temp)

# make a dataframe of the measured variables
outputs_df_low_temp = ground_truth_data(measured_var_low_temp)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2947
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      543
#
# Total number of variables............................:      909
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:      360
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      909
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.71e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.18e+00 1.26e+03  -1.0 3.81e+00    -  2.66e-03 1.97e-01f  1
#    2  0.0000000e+00 2.13e+00 1.23e+03  -1.0 4.73e+00    -  1.25e-02 2.30e-02f  1
#    3  0.0000000e+00 2.13e+00 1.23e+03  -1.0 4.81e+00    -  5.53e-02 2.91e-04h  1
#    4r 0.0000000e+00 2.13e+00 9.99e+02   0.3 0.00e+00    -  0.00e+00 3.65e-07R  4
#    5r 0.0000000e+00 2.48e+00 9.94e+02   0.3 2.78e+02    -  2.94e-03 4.81e-03f  1
#    6r 0.0000000e+00 2.41e+00 9.87e+02   0.3 1.23e+02    -  1.29e-02 7.33e-03f  1
# Mass fraction of species at the sample time: [[0.13107612150309192, 0.11828404398454924, 0.04568492534502214, 0.1795027392102609, 0.4255841550359271, 0.09986801492086408], [0.11301272220467928, 0.08574519513154158, 0.034782786716741405, 0.18493916970730892, 0.45453505414440304, 0.12698507209513246], [0.07462927467403489, 0.024890760093379708, 0.011470561894450795, 0.17984158478697906, 0.49947702915155, 0.20969078939957997]]
#
# Output variables:
#           XA        XB        XC        XP        XE        XG
# 0  0.131076  0.118284  0.045685  0.179503  0.425584  0.099868
# 1  0.113013  0.085745  0.034783  0.184939  0.454535  0.126985
# 2  0.074629  0.024891  0.011471  0.179842  0.499477  0.209691

# %%
# generate noisy mass fraction measurements
A_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XA"], mass_frac_std)
B_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XP"], mass_frac_std)
E_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XE"], mass_frac_std)
G_noisy_mass_fraction_low = generate_noisy_measurement(outputs_df_low_temp["XG"], mass_frac_std)

# define a matrix that contains the sample time and mass fractions
data_matrix_low = np.zeros((n_samples, 7))
data_matrix_low[:, 0] = sample_time_low_temp
data_matrix_low[:, 1] = A_noisy_mass_fraction_low
data_matrix_low[:, 2] = B_noisy_mass_fraction_low
data_matrix_low[:, 3] = C_noisy_mass_fraction_low
data_matrix_low[:, 4] = P_noisy_mass_fraction_low
data_matrix_low[:, 5] = E_noisy_mass_fraction_low
data_matrix_low[:, 6] = G_noisy_mass_fraction_low

# compile the generated data into a csv file
data_low_temp = synthetic_data_compiler(data_matrix_low, "batch_reactor_const_temp_low")
# Out:
# Generated data:
#     Time (hr)        XA        XB        XC        XP        XE        XG
# 0       0.75  0.144392  0.118285  0.045686  0.192819  0.438900  0.113184
# 1       1.00  0.120166  0.085746  0.034784  0.192092  0.461688  0.134138
# 2       2.50  0.059175  0.024889  0.011469  0.164388  0.484023  0.194237

# %%
# estimate the parameters
obj_low, estimated_params_low, cov_matrix_low = parameter_covariance_est(data_low_temp, XA0=0.4, XB0=0.6, 
                                                            temp_control=low_const_temp)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3753
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      552
#
# Total number of variables............................:      921
#                      variables with only lower bounds:      195
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      915
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.37e+00 1.26e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.35e+00 1.25e+00  -1.0 1.88e+00    -  1.53e-02 1.21e-02f  1
#    2  0.0000000e+00 1.35e+00 2.50e+01  -1.0 1.58e+00    -  1.15e-02 1.60e-03f  1
#    3  0.0000000e+00 2.09e+00 1.74e+02  -1.0 3.49e+00    -  4.00e-03 5.62e-01f  1
#    4  0.0000000e+00 8.58e-01 5.68e+01  -1.0 1.09e+00    -  8.67e-02 8.89e-01f  1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   2.2527111879815449e-02    2.2527111879815449e-02
# Constraint violation....:   2.0748256658783603e+01    2.0748256658783603e+01
# Complementarity.........:   9.0912988677232633e-10    9.0912988677232633e-10
# Overall NLP error.......:   2.0748256658783603e+01    2.0748256658783603e+01
#
#
# Number of objective function evaluations             = 738
# Number of objective gradient evaluations             = 130
# Number of equality constraint evaluations            = 738
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 253
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 251
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.278
# Total CPU secs in NLP function evaluations           =      0.049
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %%
print("Estimates of the original parameters:\n",estimated_params_low)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_low)
# Out:
# Estimates of the original parameters:
#  {'a1': inf, 'a2': inf, 'a3': inf, 'E1': 170582.95380114735, 'E2': 170580.33895644147, 'E3': 170581.50571102617}
#
# Covariance matrix of the original parameters:
#  ['N/A']

# %% [markdown]
# ### Parameter estimation for combined low and high temperature data

# %%
# Combine the matrices
full_data_matrix = np.vstack((data_matrix_low, data_matrix_high))

# sort by time
data_matrix_low_high = full_data_matrix[full_data_matrix[:, 0].argsort()]

# compile the generated data into a csv file
full_data_low_high = synthetic_data_compiler(data_matrix_low_high, "batch_reactor_const_temp_low_high")
# Out:
# Generated data:
#     Time (hr)        XA        XB        XC        XP        XE        XG
# 0       0.50  0.130030  0.097768  0.027704  0.181777  0.451211  0.164776
# 1       0.75  0.144392  0.118285  0.045686  0.192819  0.438900  0.113184
# 2       1.00  0.120166  0.085746  0.034784  0.192092  0.461688  0.134138
# 3       1.50  0.074381  0.023198  0.006729  0.165806  0.495214  0.263284
# 4       2.50  0.059175  0.024889  0.011469  0.164388  0.484023  0.194237
# 5       3.00  0.037988  0.006647  0.001939  0.132546  0.478134  0.280927

# %%
# redefine the model for the combined low and high temperature data
def reform_batch_reactor_model_comb(XA0, XB0):
    """
    Reformulates the variable temperature batch reactor model for parameter estimation

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp_control_points: dict,
        Piecewise-linear profile of the reaction temperature (in R)

    Returns
    -------
    model: Pyomo model of the variable temperature batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == model.alpha_1 - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == model.alpha_2 - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == model.alpha_3 - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.k[1, t] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.k[1, t] * m.XA[t] * m.XB[t] + m.k[2, t] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.k[1, t] * m.XA[t] * m.XB[t] - 2 * m.k[2, t] * m.XB[t] * m.XC[t] - m.k[3, t] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.k[2, t] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.k[3, t] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == XB0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XP_init = pyo.Constraint(expr=model.XP[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-linear temperature profile
    for t in model.t:
        if t < 0.5:
            temp_at_time_t = 6.8
    
        elif t < 1:
            temp_at_time_t = 5.8
    
        elif t < 1.5:
            temp_at_time_t = 6.8
    
        elif t < 2.5:
            temp_at_time_t = 5.8
    
        else:
            temp_at_time_t = 6.8
    
        model.T_reparam[t].fix(1 / temp_at_time_t)
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %%
# estimate the parameters
obj_comb, estimated_params_comb, cov_matrix_comb = parameter_covariance_est(full_data_low_high, XA0=0.4, XB0=0.6, 
                                                                            const_temp=False, low_high_temp=True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     4653
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      732
#
# Total number of variables............................:     1281
#                      variables with only lower bounds:      555
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1275
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.64e+00 1.15e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.59e+00 1.13e+00  -1.0 4.95e+01    -  1.77e-02 1.86e-02h  1
#    2  0.0000000e+00 1.18e+00 2.14e+01  -1.0 4.92e+01    -  2.45e-02 5.45e-01f  1
#    3  0.0000000e+00 3.27e-01 1.64e+01  -1.0 2.09e+01    -  8.93e-02 7.22e-01f  1
#    4  0.0000000e+00 1.82e-02 3.00e+01  -1.0 4.35e+00    -  6.24e-01 9.89e-01f  1
#    5  0.0000000e+00 7.20e-02 4.08e+03  -1.0 3.79e+00    -  4.79e-01 9.91e-01f  1
#    6  0.0000000e+00 4.85e-01 1.04e+05  -1.0 1.82e+01    -  2.82e-01 4.11e-01f  1
#    7  0.0000000e+00 1.98e+00 7.02e+05  -1.0 3.64e+00    -  3.36e-01 8.90e-01f  1
#    8  0.0000000e+00 3.05e-01 3.57e+06  -1.0 3.53e+00    -  3.30e-01 1.00e+00f  1
#    9  0.0000000e+00 3.11e-01 1.73e+06  -1.0 6.50e+00  -2.0 4.77e-01 2.15e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[58], line 2
#       1 # estimate the parameters
# ----> 2 obj_comb, estimated_params_comb, cov_matrix_comb = parameter_covariance_est(full_data_low_high, XA0=0.4, XB0=0.6,
#       3                                                                             const_temp=False, low_high_temp=True)
#
# Cell In[55], line 30, in parameter_covariance_est(data, XA0, XB0, temp_control, const_temp, low_high_temp)
#      27 pest = parmest.Estimator(exp_list, obj_function="SSE_weighted", tee=True)
#      29 # Estimate the reformulated parameters
# ---> 30 obj, theta = pest.theta_est()
#      32 # get the original a1, a2, and a3 parameters
#      33 a1 = np.exp(theta['alpha_1'])
#
# File ~\GitHub\pyomo\pyomo\contrib\parmest\parmest.py:1674, in Estimator.theta_est(self, solver, return_values, calc_cov, cov_n)
#    1669 elif self.pest_deprecated is not None and not calc_cov:
#    1670     return self.pest_deprecated.theta_est(
#    1671         solver=solver, return_values=return_values
#    1672     )
# -> 1674 return self._Q_opt(
#    1675     solver=solver,
#    1676     return_values=return_values,
#    1677     bootlist=None,
#    1678     calc_cov=calc_cov,
#    1679     cov_n=cov_n,
#    1680 )
#
# File ~\GitHub\pyomo\pyomo\contrib\parmest\parmest.py:1042, in Estimator._Q_opt(self, ThetaVals, solver, return_values, bootlist, calc_cov, cov_n)
#    1039             solver.options[key] = self.solver_options[key]
#    1041     solve_result = solver.solve(self.ef_instance, tee=self.tee)
# -> 1042     assert_optimal_termination(solve_result)
#    1043 elif calc_cov is not NOTSET and calc_cov:
#    1044     # parmest makes the fitted parameters stage 1 variables
#    1045     ind_vars = []
#
# File ~\GitHub\pyomo\pyomo\opt\results\solver.py:194, in assert_optimal_termination(results)
#     188 else:
#     189     msg = (
#     190         'Solver failed to return an optimal solution. '
#     191         f'Solution status: {results.solver.status}, '
#     192         f'Termination condition: {results.solver.termination_condition}'
#     193     )
# --> 194 raise RuntimeError(msg)
#
# RuntimeError: Solver failed to return an optimal solution. Solution status: warning, Termination condition: maxIterations

# %%
print(estimated_params_comb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(estimated_params_comb)
#
# NameError: name 'estimated_params_comb' is not defined

# %% [markdown]
# ## Modeling the batch reactor using a variable temperature profile

# %%
def batch_reactor_model_var(XA0, XB0, temp_control_points, meas_sample_time):
    """
    Creates a variable temperature Pyomo model for the batch reactor

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp_control_points: dict,
        Piecewise-linear profile of the reaction temperature (in R)
    meas_sample_time: list, 
        Timepoints (in hr) to collect samples for mass fraction measurements

    Returns
    -------
    measured_variables: list containing the mass fraction of all species at the sample timepoints
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.a1 = pyo.Param(within=pyo.PositiveReals, initialize=5.9755 * 10**9)
    model.a2 = pyo.Param(within=pyo.PositiveReals, initialize=2.5962 * 10**12)
    model.a3 = pyo.Param(within=pyo.PositiveReals, initialize=9.6283 * 10**15)
    model.E1 = pyo.Param(within=pyo.PositiveReals, initialize=120)
    model.E2 = pyo.Param(within=pyo.PositiveReals, initialize=150)
    model.E3 = pyo.Param(within=pyo.PositiveReals, initialize=200)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == pyo.log(m.a1) - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == pyo.log(m.a2) - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == pyo.log(m.a3) - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.r[1, t] 
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.r[1, t] + m.r[2, t])

    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.r[1, t] - 2 * m.r[2, t] - m.r[3, t] 

    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.r[2, t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.r[3, t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA[t0].fix(XA0)
    model.XB[t0].fix(XB0)
    model.XC[t0].fix(0)
    model.XE[t0].fix(0)
    model.XP[t0].fix(0)
    model.XG[t0].fix(0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-linear temperature profile
    for t in model.t:
        if t < 0.5:
            temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        elif t < 1.0:
            temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        elif t < 1.5:
            temp_at_time_t = temp_control_points["1.0"] + 0.4 * (t - 1.0)
    
        elif t < 2.0:
            temp_at_time_t = temp_control_points["1.5"] + 0.4 * (t - 1.5)
    
        else:
            temp_at_time_t = temp_control_points["2.0"] + 0.2 * (t - 2.0)
    
        model.T_reparam[t].fix(1 / temp_at_time_t)

    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    # model.pprint()

    # get the mass fraction of all species
    time = [t for t in model.t]
    print("The timepoints are:",time)
    XA_values = [pyo.value(model.XA[t]) for t in model.t]
    XB_values = [pyo.value(model.XB[t]) for t in model.t] 
    XC_values = [pyo.value(model.XC[t]) for t in model.t] 
    XP_values = [pyo.value(model.XP[t]) for t in model.t] 
    XE_values = [pyo.value(model.XE[t]) for t in model.t] 
    XG_values = [pyo.value(model.XG[t]) for t in model.t]

     # Plot the results
    temp_values = [1 / pyo.value(model.T_reparam[t]) for t in model.t]
    plt.figure(figsize=(8, 6))
    plt.plot(time, temp_values,)
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Temperature (R)', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(time, XA_values, label='A')
    plt.plot(time, XB_values, label='B')
    plt.plot(time, XC_values, label='C')
    plt.plot(time, XP_values, label='P')
    plt.plot(time, XE_values, label='E')
    plt.plot(time, XG_values, label='G')
    plt.xlabel('Time (hr)', fontsize=16,fontweight='bold')
    plt.ylabel('Mass Fraction', fontsize=16,fontweight='bold')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(prop={"weight":"bold", "size": 11}, bbox_to_anchor=(1, 0.5))
    plt.savefig("batch_reactor_var_temp.png")
    plt.show()

    # store the mass fraction of all species at the sample time
    measured_variables = []
    for sample_time in meas_sample_time:
        measured_variables.append([pyo.value(model.XA[sample_time]), pyo.value(model.XB[sample_time]), pyo.value(model.XC[sample_time]), 
                                   pyo.value(model.XP[sample_time]), pyo.value(model.XE[sample_time]), pyo.value(model.XG[sample_time])])

    print("Mass fraction of species at the sample time:",measured_variables)
    return measured_variables

# %%
# define the temperature control points and sample time for mass fraction measurements
temp_control = {"0.0":5.8, "0.5":5.9, "1.0":6.2, "1.5":6.4, "2.0":6.6, "3.0":6.8}
meas_sample_time_var = [0.5, 1.5, 3]

# get the ground-truth simulation of the mass fractions
measured_var = batch_reactor_model_var(0.4, 0.6, temp_control, meas_sample_time_var)

# make a dataframe of the measured variables
measured_var_df = ground_truth_data(measured_var)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3487
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      723
#
# Total number of variables............................:     1269
#                      variables with only lower bounds:      549
#                 variables with lower and upper bounds:      360
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1269
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 7.38e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 6.49e+00 1.01e+02  -1.0 8.46e+00    -  1.18e-03 1.21e-01f  1
#    2  0.0000000e+00 6.44e+00 1.00e+02  -1.0 1.74e+01    -  5.34e-03 7.57e-03f  1
#    3  0.0000000e+00 6.44e+00 4.25e+02  -1.0 1.81e+01    -  1.76e-02 8.29e-05h  1
#    4r 0.0000000e+00 6.44e+00 9.99e+02   0.8 0.00e+00    -  0.00e+00 4.15e-07R  2
#    5r 0.0000000e+00 6.46e+00 9.92e+02   0.8 1.90e+02    -  3.41e-03 7.42e-03f  1
#    6r 0.0000000e+00 6.24e+00 9.86e+02   0.8 1.10e+02    -  9.20e-03 5.29e-03f  1
#    7r 0.0000000e+00 6.20e+00 1.66e+03   0.8 8.40e+01    -  4.69e-02 1.62e-03f  1
#    8r 0.0000000e+00 5.76e+00 1.97e+03   0.8 7.96e+01    -  2.85e-02 1.81e-02f  1
#    9r 0.0000000e+00 5.51e+00 2.65e+03   0.8 5.06e+01    -  8.68e-02 2.62e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 5.14e+00 2.74e+03   0.8 3.74e+01    -  1.01e-01 6.62e-02f  1
#   11r 0.0000000e+00 4.86e+00 3.85e+03   0.8 2.36e+01    -  2.78e-01 1.16e-01f  1
#   12r 0.0000000e+00 4.69e+00 3.66e+03   0.8 1.54e+01    -  3.78e-01 1.58e-01f  1
#   13r 0.0000000e+00 4.50e+00 3.31e+03   0.8 1.06e+01    -  1.77e-01 3.02e-01f  1
#   14r 0.0000000e+00 4.39e+00 2.06e+03   0.8 5.84e+00    -  4.01e-01 4.13e-01f  1
#   15r 0.0000000e+00 4.33e+00 4.56e+02   0.8 2.97e+00    -  6.89e-01 6.28e-01h  1
#   16r 0.0000000e+00 4.30e+00 1.02e+03   0.8 1.01e+00    -  6.34e-01 1.00e+00h  1
#   17r 0.0000000e+00 4.30e+00 1.13e+01   0.8 5.88e-02    -  1.00e+00 1.00e+00h  1
#   18r 0.0000000e+00 4.30e+00 5.52e+01  -1.3 5.47e-01    -  6.53e-01 7.34e-01f  1
#   19r 0.0000000e+00 4.20e+00 8.09e+02  -1.3 1.83e+01    -  5.44e-01 1.18e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   
#
# Output variables:
#           XA        XB        XC        XP        XE        XG
# 0  0.147466  0.149061  0.049150  0.168849  0.396809  0.088665
# 1  0.058550  0.012407  0.001581  0.151628  0.492287  0.283547
# 2  0.046738  0.000036  0.000002  0.140144  0.493405  0.319675

# %% [markdown]
# ### Add Gaussian noise to the ground-truth simulations

# %%
# generate noisy mass fraction measurements
A_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XA"], mass_frac_std)
B_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XB"], B_C_mass_frac_std)
C_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XC"], B_C_mass_frac_std)
P_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XP"], mass_frac_std)
E_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XE"], mass_frac_std)
G_noisy_mass_fraction_var = generate_noisy_measurement(measured_var_df["XG"], mass_frac_std)

# define a matrix that contains the sample time and mass fractions
data_matrix_var = np.zeros((n_samples, 7))
data_matrix_var[:, 0] = meas_sample_time_var
data_matrix_var[:, 1] = A_noisy_mass_fraction_var
data_matrix_var[:, 2] = B_noisy_mass_fraction_var
data_matrix_var[:, 3] = C_noisy_mass_fraction_var
data_matrix_var[:, 4] = P_noisy_mass_fraction_var
data_matrix_var[:, 5] = E_noisy_mass_fraction_var
data_matrix_var[:, 6] = G_noisy_mass_fraction_var

# %% [markdown]
# ### Compile the generated data into a csv file

# %%
data_var = synthetic_data_compiler(data_matrix_var, "batch_reactor_var_temp")
# Out:
# Generated data:
#     Time (hr)        XA        XB            XC        XP        XE        XG
# 0        0.5  0.160781  0.149063  4.915132e-02  0.182165  0.410125  0.101981
# 1        1.5  0.065703  0.012407  1.581349e-03  0.158781  0.499440  0.290700
# 2        3.0  0.031284  0.000035  4.352556e-07  0.124690  0.477951  0.304221

# %% [markdown]
# ### Reformulate the batch reactor model for parameter estimation

# %%
def reform_batch_reactor_model_var(XA0, XB0, temp_control_points):
    """
    Reformulates the variable temperature batch reactor model for parameter estimation

    Parameters
    ----------
    XA0: float,
        Initial mass fraction of species A
    XB0: float,
        Initial mass fraction of species B
    temp_control_points: dict,
        Piecewise-linear profile of the reaction temperature (in R)

    Returns
    -------
    model: Pyomo model of the variable temperature batch reactor
    
    """
    model = pyo.ConcreteModel()

    # define sets
    reaction_number = [1, 2, 3]
    model.t = dae.ContinuousSet(bounds=[0, 3]) # hour

    # define the model parameters
    model.alpha_1 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_2 = pyo.Var(bounds=(0, None), initialize=10)
    model.alpha_3 = pyo.Var(bounds=(0, None), initialize=10)
    model.E1 = pyo.Var(bounds=(0, None), initialize=50)
    model.E2 = pyo.Var(bounds=(0, None), initialize=50)
    model.E3 = pyo.Var(bounds=(0, None), initialize=50)
    
    # add the mass fraction variables
    model.XA = pyo.Var(model.t, bounds=(0, 1), initialize=XA0)
    model.XB = pyo.Var(model.t, bounds=(0, 1), initialize=XB0)
    model.XC = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XE = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XP = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)
    model.XG = pyo.Var(model.t, bounds=(0, 1), initialize=0.01)

    # add the temperature variables
    model.T_reparam = pyo.Var(model.t, bounds=(0, 1))

    # add the rate constants
    model.k_reparam = pyo.Var(reaction_number, model.t, bounds=(0, None))
    model.k = pyo.Var(reaction_number, model.t, bounds=(0, None))
    
    # calculate the reparameterized rate constants
    def k_reparam_rule(m, i, t):
        if i == 1:
            return m.k_reparam[i, t] == model.alpha_1 - m.E1 * m.T_reparam[t]
        elif i == 2:
            return m.k_reparam[i, t] == model.alpha_2 - m.E2 * m.T_reparam[t]
        else:
            return m.k_reparam[i, t] == model.alpha_3 - m.E3 * m.T_reparam[t]
            
    model.k_reparam_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_reparam_rule
    )
    
    # calculate the original rate constants
    def k_rule(m, i, t):
        return m.k[i, t] == pyo.exp(m.k_reparam[i, t])
    
    model.k_eq = pyo.Constraint(
        reaction_number, model.t, rule=k_rule
    )

    # reaction rates
    model.r = pyo.Var(reaction_number, model.t, bounds=(0, None),)
    
    # define the rate of reactions
    def reaction_rate_rule(m, i, t):
        if i == 1:
            return m.r[i, t] == m.k[i, t] * m.XA[t] * m.XB[t]
        elif i == 2:
            return m.r[i, t] == m.k[i, t] * m.XB[t] * m.XC[t]
        else:
            return m.r[i, t] == m.k[i, t] * m.XC[t] * m.XP[t]
    
    model.reaction_rate = pyo.Constraint(
        reaction_number, model.t, rule=reaction_rate_rule
    )

    # add the differential equations for XA, XB, XC, XE, XP, and XG
    model.dXA = dae.DerivativeVar(model.XA, wrt=model.t)
    model.dXB = dae.DerivativeVar(model.XB, wrt=model.t)
    model.dXC = dae.DerivativeVar(model.XC, wrt=model.t)
    model.dXE = dae.DerivativeVar(model.XE, wrt=model.t)
    model.dXP = dae.DerivativeVar(model.XP, wrt=model.t)
    model.dXG = dae.DerivativeVar(model.XG, wrt=model.t)

    @model.Constraint(model.t)
    def xa_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXA[t] == - m.k[1, t] * m.XA[t] * m.XB[t]
    
    @model.Constraint(model.t)
    def xb_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXB[t] == - (m.k[1, t] * m.XA[t] * m.XB[t] + m.k[2, t] * m.XB[t] * m.XC[t])
    
    @model.Constraint(model.t)
    def xc_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXC[t] == 2 * m.k[1, t] * m.XA[t] * m.XB[t] - 2 * m.k[2, t] * m.XB[t] * m.XC[t] - m.k[3, t] * m.XC[t] * m.XP[t]
    
    @model.Constraint(model.t)
    def xe_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXE[t] == 2 * m.k[2, t] * m.XB[t] * m.XC[t]
    
    @model.Constraint(model.t)
    def xg_rate_ode(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.dXG[t] == 1.5 * m.k[3, t] * m.XC[t] * m.XP[t]

    # add the mass fraction constraint
    @model.Constraint(model.t)
    def sum_mass_fraction(m, t):
        if t == m.t.first():
            return pyo.Constraint.Skip
        return m.XA[t] + m.XB[t] + m.XC[t] + m.XE[t] + m.XG[t] + m.XP[t] == 1

    # fix the initial conditions
    t0 = model.t.first()
    model.XA_init = pyo.Constraint(expr=model.XA[t0] == XA0)
    model.XB_init = pyo.Constraint(expr=model.XB[t0] == XB0)
    model.XC_init = pyo.Constraint(expr=model.XC[t0] == 0.0)
    model.XE_init = pyo.Constraint(expr=model.XE[t0] == 0.0)
    model.XP_init = pyo.Constraint(expr=model.XP[t0] == 0.0)
    model.XG_init = pyo.Constraint(expr=model.XG[t0] == 0.0)

    # discretize the model
    disc = pyo.TransformationFactory("dae.finite_difference")
    disc.apply_to(model, nfe=60, scheme="BACKWARD")

    # add a piecewise-linear temperature profile
    for t in model.t:
        if t < 0.5:
            temp_at_time_t = temp_control_points["0.0"] + 0.2 * t
    
        elif t < 1.0:
            temp_at_time_t = temp_control_points["0.5"] + 0.6 * (t - 0.5)
    
        elif t < 1.5:
            temp_at_time_t = temp_control_points["1.0"] + 0.4 * (t - 1.0)
    
        elif t < 2.0:
            temp_at_time_t = temp_control_points["1.5"] + 0.4 * (t - 1.5)
    
        else:
            temp_at_time_t = temp_control_points["2.0"] + 0.2 * (t - 2.0)
    
        model.T_reparam[t].fix(1 / temp_at_time_t)
    
    # define the solver
    solver = pyo.SolverFactory('ipopt')
    
    # solve the model
    results = solver.solve(model, tee=True)
    
    return model

# %% [markdown]
# ### Estimate the unknown model parameters

# %%
objective_val, estimated_params, cov_matrix_est = parameter_covariance_est(data_var, XA0=0.4, XB0=0.6, 
                                                            temp_control=temp_control, const_temp=False)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     4653
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      732
#
# Total number of variables............................:     1281
#                      variables with only lower bounds:      555
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1275
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.64e+00 1.15e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.59e+00 1.13e+00  -1.0 4.87e+01    -  1.75e-02 1.70e-02h  1
#    2  0.0000000e+00 1.18e+00 4.32e+01  -1.0 4.93e+01    -  2.07e-02 5.47e-01f  1
#    3  0.0000000e+00 2.34e-01 1.78e+01  -1.0 2.13e+01    -  8.85e-02 8.01e-01f  1
#    4  0.0000000e+00 1.02e-02 3.68e+01  -1.0 3.03e+00    -  6.67e-01 9.89e-01f  1
#    5  0.0000000e+00 9.99e-02 7.90e+03  -1.0 5.06e+00    -  2.83e-01 9.91e-01f  1
#    6  0.0000000e+00 7.28e-01 5.95e+05  -1.0 1.54e+00    -  4.63e-01 1.00e+00f  1
#    7  0.0000000e+00 1.17e+00 1.20e+06  -1.0 1.28e+01  -2.0 3.10e-01 3.98e-01f  1
#    8  0.0000000e+00 3.01e-01 1.09e+06  -1.0 4.98e+00  -1.6 8.80e-01 1.00e+00f  1
#    9  0.0000000e+00 1.02e+01 6.32e+06  -1.0 1.22e+02    -  1.56e-01 7.76e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10
  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  0.0000000e+00 8.90e+01 5.25e-01  -5.7 1.44e+03    -  7.17e-01 1.00e+00H  1
#   31  0.0000000e+00 4.30e+02 3.28e-01  -5.7 5.42e+03    -  3.75e-01 4.86e-01H  1
#   32  0.0000000e+00 1.14e+03 1.83e-01  -5.7 1.33e+04    -  4.44e-01 1.00e+00H  1
#   33  0.0000000e+00 1.04e+02 5.51e-01  -5.7 3.20e+00  -3.1 1.00e+00 1.00e+00h  1
#   34  0.0000000e+00 7.03e-01 7.84e-02  -5.7 1.09e+00  -3.5 1.00e+00 1.00e+00h  1
#   35  0.0000000e+00 8.01e-05 1.98e-04  -5.7 4.58e-02  -4.0 1.00e+00 1.00e+00h  1
#   36  0.0000000e+00 1.78e+01 1.12e-02  -5.7 2.45e+04    -  1.82e-01 3.97e-02h  3
#   37  0.0000000e+00 1.78e+01 5.95e-02  -5.7 2.77e+04    -  9.04e-01 6.48e-04h 10
#   38  0.0000000e+00 1.72e-02 5.00e-05  -5.7 3.71e-01  -4.5 1.00e+00 1.00e+00h  1
#   39  0.0000000e+00 6.25e-06 5.88e-07  -5.7 5.42e-02  -5.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  0.0000000e+00 4.65e-11 2.20e-05  -8.6 2.28e-04  -5.4 1.00e+00 1.00e+00h  1
#   41  0.0000000e+00 3.65e-10 8.14e-10  -8.6 6.76e-04  -5.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 41
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   8.1382511035031389e-10    8.1382511035031389e-10
# Constraint violation....:   3.6540193093514972e-10    3.6540193093514972e-10
# Complementarity.........:   2.5059041525070288e-09    2.5059041525070288e-09
# Overall NLP error.......:   2.5059041525070288e-09    2.5059041525070288e-09
#
#
# Number of objective function evaluations             = 95
# Number of objective gradient evaluations             = 42
# Number of equality constraint evaluations            = 95
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 42
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 41
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.341
# Total CPU secs in NLP function evaluations           =      0.020
#
# EXIT: Optimal Solution Found.

# %%
print("Estimates of the original parameters:\n",estimated_params)
print("\nCovariance matrix of the original parameters:\n",cov_matrix_est)
# Out:
# Estimates of the original parameters:
#  {'a1': 6680210386.22043, 'a2': 1264522326501.0642, 'a3': 1.4600735908262762e+16, 'E1': 120.6670992737492, 'E2': 145.74520180506875, 'E3': 202.57649335200497}
#
# Covariance matrix of the original parameters:
#                a1            a2            a3            E1            E2  \
# a1  6.719927e+17  9.916467e+19 -2.285840e+24  5.708811e+08  4.893155e+08
# a2  9.916464e+19  6.122149e+23 -5.405046e+27  6.418654e+10  2.883989e+12
# a3 -2.285840e+24 -5.405046e+27  5.078509e+31 -1.771747e+15 -2.550958e+16
# E1  5.708811e+08  6.418656e+10 -1.771747e+15  4.856566e-01  3.213155e-01
# E2  4.893154e+08  2.883989e+12 -2.550958e+16  3.213153e-01  1.358649e+01
# E3 -1.082109e+09 -2.380490e+12  2.252810e+16 -8.447246e-01 -1.123747e+01
#
#               E3
# a1 -1.082109e+09
# a2 -2.380490e+12
# a3  2.252810e+16
# E1 -8.447247e-01
# E2 -1.123747e+01
# E3  1.000156e+01
